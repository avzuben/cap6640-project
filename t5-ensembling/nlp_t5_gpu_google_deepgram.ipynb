# %%
# !pip install transformers[sentencepiece]
# Out:
# Collecting transformers[sentencepiece]
#   Downloading transformers-4.18.0-py3-none-any.whl (4.0 MB)
#      |████████████████████████████████| 4.0 MB 5.2 MB/s
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 22.6 MB/s
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 7.9 MB/s
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers[sentencepiece]) (4.11.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers[sentencepiece]) (3.6.0)
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.5.1-py3-none-any.whl (77 kB)
#      |████████████████████████████████| 77 kB 5.0 MB/s
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers[sentencepiece]) (1.21.6)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers[sentencepiece]) (4.64.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers[sentencepiece]) (21.3)
# Collecting sacremoses
#   Downloading sacremoses-0.0.49-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 56.7 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers[sentencepiece]) (2019.12.20)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers[sentencepiece]) (2.23.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.7/dist-packages (from transformers[sentencepiece]) (3.17.3)
# Collecting sentencepiece!=0.1.92,>=0.1.91
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 48.6 MB/s
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers[sentencepiece]) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers[sentencepiece]) (3.0.8)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers[sentencepiece]) (3.8.0)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.7/dist-packages (from protobuf->transformers[sentencepiece]) (1.15.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers[sentencepiece]) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers[sentencepiece]) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers[sentencepiece]) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers[sentencepiece]) (1.24.3)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers[sentencepiece]) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers[sentencepiece]) (1.1.0)
# Installing collected packages: pyyaml, tokenizers, sacremoses, huggingface-hub, transformers, sentencepiece
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed huggingface-hub-0.5.1 pyyaml-6.0 sacremoses-0.0.49 sentencepiece-0.1.96 tokenizers-0.12.1 transformers-4.18.0

# %%
# !pip install datasets
# Out:
# Collecting datasets
#   Downloading datasets-2.1.0-py3-none-any.whl (325 kB)
#      |████████████████████████████████| 325 kB 5.1 MB/s
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from datasets) (1.21.6)
# Collecting xxhash
#   Downloading xxhash-3.0.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      |████████████████████████████████| 212 kB 62.6 MB/s
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.7/dist-packages (from datasets) (4.64.0)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (0.5.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from datasets) (1.3.5)
# Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from datasets) (0.3.4)
# Collecting fsspec[http]>=2021.05.0
#   Downloading fsspec-2022.3.0-py3-none-any.whl (136 kB)
#      |████████████████████████████████| 136 kB 63.0 MB/s
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from datasets) (4.11.3)
# Collecting aiohttp
#   Downloading aiohttp-3.8.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 51.8 MB/s
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (2.23.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.7/dist-packages (from datasets) (0.70.12.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from datasets) (21.3)
# Requirement already satisfied: pyarrow>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (3.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->datasets) (3.0.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (2.10)
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 20.6 MB/s
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.2.0-py3-none-any.whl (8.2 kB)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (94 kB)
#      |████████████████████████████████| 94 kB 3.1 MB/s
# Collecting asynctest==0.13.0
#   Downloading asynctest-0.13.0-py3-none-any.whl (26 kB)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (2.0.12)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.7.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (271 kB)
#      |████████████████████████████████| 271 kB 15.7 MB/s
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (144 kB)
#      |████████████████████████████████| 144 kB 57.8 MB/s
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (21.4.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->datasets) (3.8.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->datasets) (1.15.0)
# Installing collected packages: multidict, frozenlist, yarl, urllib3, asynctest, async-timeout, aiosignal, fsspec, aiohttp, xxhash, responses, datasets
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed aiohttp-3.8.1 aiosignal-1.2.0 async-timeout-4.0.2 asynctest-0.13.0 datasets-2.1.0 frozenlist-1.3.0 fsspec-2022.3.0 multidict-6.0.2 responses-0.18.0 urllib3-1.25.11 xxhash-3.0.0 yarl-1.7.2

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
from transformers import AutoTokenizer
from transformers import AutoModelForSeq2SeqLM, Seq2SeqTrainingArguments, Seq2SeqTrainer

tokenizer = AutoTokenizer.from_pretrained("t5-small")
model = AutoModelForSeq2SeqLM.from_pretrained("t5-small")
# Out:
# Downloading:   0%|          | 0.00/1.17k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/773k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.32M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/231M [00:00<?, ?B/s]

# %%
import numpy as np
import pandas as pd

# DS_DIR = './'
DS_DIR = '/content/gdrive/My Drive/'
label = 'text1'
models = ['google', 'wit', 'deepgram']


def load_data(model):
    df = pd.read_csv(DS_DIR + 'ljs-data.csv')
    train_df, valid_df = np.split(df.sample(frac=1, random_state=42), [int(.8 * len(df))])
    errors_train = train_df['google'].isna().values | train_df['wit'].isna().values | train_df['deepgram'].isna().values
    y_train = train_df[label].values
    X_train = train_df[model].values
    errors_valid = valid_df['google'].isna().values | valid_df['wit'].isna().values | valid_df['deepgram'].isna().values
    y_valid = valid_df[label].values
    X_valid = valid_df[model].values
    return X_train[~errors_train], y_train[~errors_train], X_valid[~errors_valid], y_valid[~errors_valid]

# %%
X1_train, y1_train, X1_valid, y1_valid = load_data('google')
X2_train, y2_train, X2_valid, y2_valid = load_data('deepgram')

# %%
from datasets import Dataset

df_train = pd.DataFrame({"text1": X1_train, "text2": X2_train, "labels": y1_train})
dataset_train = Dataset.from_pandas(df_train)

df_valid = pd.DataFrame({"text1": X1_valid, "text2": X2_valid, "labels": y1_valid})
dataset_valid = Dataset.from_pandas(df_valid)

# %%
prefix = "merge sentence1: "
infix = " sentence2: "

def preprocess_function(examples):
    inputs = [prefix + examples["text1"][i] + infix + examples["text2"][i] for i in range(len(examples["text1"]))]
    model_inputs = tokenizer(inputs, padding="max_length", max_length=320, truncation=True)

    with tokenizer.as_target_tokenizer():
        labels = tokenizer(examples['labels'], padding="max_length", max_length=320, truncation=True)

    # model_inputs["input_ids"] = model_inputs["input_ids"].squeeze(0)
    # model_inputs["attention_mask"] = model_inputs["attention_mask"].squeeze(0)
    model_inputs["labels"] = labels["input_ids"] #.squeeze(0)

    return model_inputs

tokenized_datasets_train = dataset_train.map(preprocess_function, batched=True)
tokenized_datasets_valid = dataset_valid.map(preprocess_function, batched=True)
# Out:
#   0%|          | 0/11 [00:00<?, ?ba/s]
#   0%|          | 0/3 [00:00<?, ?ba/s]

# %%
tokenized_datasets_train = tokenized_datasets_train.remove_columns(["text1", "text2"])
tokenized_datasets_valid = tokenized_datasets_valid.remove_columns(["text1", "text2"])
# tokenized_datasets.set_format("torch")
tokenized_datasets_train
# Out:
# Dataset({
#     features: ['labels', 'input_ids', 'attention_mask'],
#     num_rows: 10477
# })

# %%
from transformers import DataCollatorForSeq2Seq

data_collator = DataCollatorForSeq2Seq(tokenizer=tokenizer, model=model)

# %%
training_args = Seq2SeqTrainingArguments(
    output_dir="./results-google-deepgram",
    evaluation_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    weight_decay=0.01,
    save_total_limit=3,
    num_train_epochs=100,
    fp16=True,
)

# %%
trainer = Seq2SeqTrainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_datasets_train,
    eval_dataset=tokenized_datasets_valid,
    tokenizer=tokenizer,
    data_collator=data_collator,
)
# Out:
# Using amp half precision backend

# %%
trainer.train()
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:309: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 10477
#   Num Epochs = 100
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 16
#   Gradient Accumulation steps = 1
#   Total optimization steps = 65500
#     <div>
#
#       <progress value='65500' max='65500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [65500/65500 6:52:40, Epoch 100/100]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.602100</td>
#       <td>0.050654</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.061600</td>
#       <td>0.041168</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.049900</td>
#       <td>0.037977</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.043100</td>
#       <td>0.035917</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.041400</td>
#       <td>0.034128</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.039600</td>
#       <td>0.032885</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.037100</td>
#       <td>0.032062</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.035800</td>
#       <td>0.031144</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.034800</td>
#       <td>0.030325</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.033100</td>
#       <td>0.029913</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.032100</td>
#       <td>0.029510</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.031600</td>
#       <td>0.028921</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.030700</td>
#       <td>0.028604</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.029800</td>
#       <td>0.028228</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.029400</td>
#       <td>0.027955</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.028700</td>
#       <td>0.027754</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.027800</td>
#       <td>0.027397</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.027600</td>
#       <td>0.027340</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.027100</td>
#       <td>0.027162</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.026400</td>
#       <td>0.026917</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.025900</td>
#       <td>0.026810</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.025900</td>
#       <td>0.026648</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.025000</td>
#       <td>0.026363</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.024500</td>
#       <td>0.026390</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.024800</td>
#       <td>0.026160</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.024100</td>
#       <td>0.026238</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.023500</td>
#       <td>0.026139</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.023000</td>
#       <td>0.026047</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.023200</td>
#       <td>0.025956</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.022800</td>
#       <td>0.025851</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.022000</td>
#       <td>0.025816</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.022300</td>
#       <td>0.025753</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.022000</td>
#       <td>0.025827</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.021400</td>
#       <td>0.025608</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.021300</td>
#       <td>0.025569</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.020800</td>
#       <td>0.025607</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.020700</td>
#       <td>0.025472</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.020400</td>
#       <td>0.025534</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.020200</td>
#       <td>0.025445</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.019800</td>
#       <td>0.025391</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.020200</td>
#       <td>0.025383</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.019600</td>
#       <td>0.025538</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.019500</td>
#       <td>0.025353</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>0.019200</td>
#       <td>0.025399</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.019300</td>
#       <td>0.025318</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.018900</td>
#       <td>0.025287</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>0.018700</td>
#       <td>0.025442</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.018700</td>
#       <td>0.025447</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.018500</td>
#       <td>0.025393</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.018100</td>
#       <td>0.025334</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>0.018300</td>
#       <td>0.025417</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>0.017800</td>
#       <td>0.025286</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>0.017900</td>
#       <td>0.025397</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>0.017500</td>
#       <td>0.025449</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>0.017500</td>
#       <td>0.025377</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>0.017300</td>
#       <td>0.025332</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>0.017100</td>
#       <td>0.025419</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>0.017200</td>
#       <td>0.025454</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>0.016900</td>
#       <td>0.025433</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.016900</td>
#       <td>0.025496</td>
#     </tr>
#     <tr>
#       <td>61</td>
#       <td>0.016700</td>
#       <td>0.025447</td>
#     </tr>
#     <tr>
#       <td>62</td>
#       <td>0.016900</td>
#       <td>0.025543</td>
#     </tr>
#     <tr>
#       <td>63</td>
#       <td>0.016300</td>
#       <td>0.025505</td>
#     </tr>
#     <tr>
#       <td>64</td>
#       <td>0.016600</td>
#       <td>0.025422</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>0.016400</td>
#       <td>0.025430</td>
#     </tr>
#     <tr>
#       <td>66</td>
#       <td>0.016400</td>
#       <td>0.025446</td>
#     </tr>
#     <tr>
#       <td>67</td>
#       <td>0.016200</td>
#       <td>0.025516</td>
#     </tr>
#     <tr>
#       <td>68</td>
#       <td>0.016300</td>
#       <td>0.025566</td>
#     </tr>
#     <tr>
#       <td>69</td>
#       <td>0.016100</td>
#       <td>0.025577</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.015800</td>
#       <td>0.025543</td>
#     </tr>
#     <tr>
#       <td>71</td>
#       <td>0.015900</td>
#       <td>0.025475</td>
#     </tr>
#     <tr>
#       <td>72</td>
#       <td>0.015800</td>
#       <td>0.025616</td>
#     </tr>
#     <tr>
#       <td>73</td>
#       <td>0.015600</td>
#       <td>0.025596</td>
#     </tr>
#     <tr>
#       <td>74</td>
#       <td>0.015700</td>
#       <td>0.025543</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>0.015700</td>
#       <td>0.025608</td>
#     </tr>
#     <tr>
#       <td>76</td>
#       <td>0.015300</td>
#       <td>0.025558</td>
#     </tr>
#     <tr>
#       <td>77</td>
#       <td>0.015500</td>
#       <td>0.025600</td>
#     </tr>
#     <tr>
#       <td>78</td>
#       <td>0.015500</td>
#       <td>0.025646</td>
#     </tr>
#     <tr>
#       <td>79</td>
#       <td>0.015300</td>
#       <td>0.025673</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.014800</td>
#       <td>0.025671</td>
#     </tr>
#     <tr>
#       <td>81</td>
#       <td>0.015500</td>
#       <td>0.025618</td>
#     </tr>
#     <tr>
#       <td>82</td>
#       <td>0.015100</td>
#       <td>0.025627</td>
#     </tr>
#     <tr>
#       <td>83</td>
#       <td>0.015100</td>
#       <td>0.025643</td>
#     </tr>
#     <tr>
#       <td>84</td>
#       <td>0.015100</td>
#       <td>0.025735</td>
#     </tr>
#     <tr>
#       <td>85</td>
#       <td>0.015200</td>
#       <td>0.025727</td>
#     </tr>
#     <tr>
#       <td>86</td>
#       <td>0.014500</td>
#       <td>0.025694</td>
#     </tr>
#     <tr>
#       <td>87</td>
#       <td>0.015100</td>
#       <td>0.025698</td>
#     </tr>
#     <tr>
#       <td>88</td>
#       <td>0.015000</td>
#       <td>0.025707</td>
#     </tr>
#     <tr>
#       <td>89</td>
#       <td>0.014900</td>
#       <td>0.025686</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>0.014800</td>
#       <td>0.02
# Saving model checkpoint to ./results-google-deepgram/checkpoint-500
# Configuration saved in ./results-google-deepgram/checkpoint-500/config.json
# Model weights saved in ./results-google-deepgram/checkpoint-500/pytorch_model.bin
# tokenizer config file saved in ./results-google-deepgram/checkpoint-500/tokenizer_config.json
# Special tokens file saved in ./results-google-deepgram/checkpoint-500/special_tokens_map.json
# Copy vocab file to ./results-google-deepgram/checkpoint-500/spiece.model
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-deepgram/checkpoint-1000
# Configuration saved in ./results-google-deepgram/checkpoint-1000/config.json
# Model weights saved in ./results-google-deepgram/checkpoint-1000/pytorch_model.bin
# tokenizer config file saved in ./results-google-deepgram/checkpoint-1000/tokenizer_config.json
# Special tokens file saved in ./results-google-deepgram/checkpoint-1000/special_tokens_map.json
# Copy vocab file to ./results-google-deepgram/checkpoint-1000/spiece.model
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-deepgram/checkpoint-1500
# Configuration saved in ./results-google-deepgram/checkpoint-1500/config.json
# Model weights saved in ./results-google-deepgram/checkpoint-1500/pytorch_model.bin
# tokenizer config file saved in ./results-google-deepgram/checkpoint-1500/tokenizer_config.json
# Special tokens file saved in ./results-google-deepgram/checkpoint-1500/special_tokens_map.json
# Copy vocab file to ./results-google-deepgram/checkpoint-1500/spiece.model
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-deepgram/checkpoint-2000
# Configuration saved in ./results-google-deepgram/checkpoint-2000/config.json
# Model weights saved in ./results-google-deepgram/checkpoint-2000/pytorch_model.bin
# tokenizer config file saved in ./results-google-deepgram/checkpoint-2000/tokenizer_config.json
# Special tokens file saved in ./results-google-deepgram/checkpoint-2000/special_tokens_map.json
# Copy vocab file to ./results-google-deepgram/checkpoint-2000/spiece.model
# Deleting older checkpoint [results-google-deepgram/checkpoint-500] due to args.save_total_limit
# Saving model checkpoint to ./results-google-deepgram/checkpoint-2500
# Configuration saved in ./results-google-deepgram/checkpoint-2500/config.json
# Model weights saved in ./results-google-deepgram/checkpoint-2500/pytorch_model.bin
# tokenizer config file saved in ./results-google-deepgram/checkpoint-2500/tokenizer_config.json
# Special tokens file saved in ./results-google-deepgram/checkpoint-2500/special_tokens_map.json
# Copy vocab file to ./results-google-deepgram/checkpoint-2500/spiece.model
# Deleting older checkpoint [results-google-deepgram/checkpoint-1000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-deepgram/checkpoint-3000
# Configuration saved in ./results-google-deepgram/checkpoint-3000/config.json
# Model weights saved in ./results-google-deepgram/checkpoint-3000/pytorch_model.bin
# tokenizer config file saved in ./results-google-deepgram/checkpoint-3000/tokenizer_config.json
# Special tokens file saved in ./results-google-deepgram/checkpoint-3000/special_tokens_map.json
# Copy vocab file to ./results-google-deepgram/checkpoint-3000/spiece.model
# Deleting older checkpoint [results-google-deepgram/checkpoint-1500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-deepgram/checkpoint-3500
# Configuration saved in ./results-google-deepgram/checkpoint-3500/config.json
# Model weights saved in ./results-google-deepgram/checkpoint-3500/pytorch_model.bin
# tokenizer config file saved in ./results-google-deepgram/checkpoint-3500/tokenizer_config.json
# Special tokens file saved in ./results-google-deepgram/checkpoint-3500/special_tokens_map.json
# Copy vocab file to ./results-google-deepgram/checkpoint-3500/spiece.model
# Deleting older checkpoint [results-google-deepgram/checkpoint-2000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-deepgram/checkpoint-4000
# Configuration saved in ./results-google-deepgram/checkpoint-4000/config.json
# Model weights saved in ./results-google-deepgram/checkpoint-4000/pytorch_model.bin
# tokenizer config file saved in ./results-google-deepgram/checkpoint-4000/tokenizer_config.json
# Special tokens file saved in ./results-google-deepgram/checkpoint-4000/special_tokens_map.json
# Copy vocab file to ./results-google-deepgram/checkpoint-4000/spiece.model
# Deleting older checkpoint [results-google-deepgram/checkpoint-2500] due to args.save_total_limit
# Saving model checkpoint to ./results-google-deepgram/checkpoint-4500
# Configuration saved in ./results-google-deepgram/checkpoint-4500/config.json
# Model weights saved in ./results-google-deepgram/checkpoint-4500/pytorch_model.bin
# tokenizer config file saved in ./results-google-deepgram/checkpoint-4500/tokenizer_config.json
# Special tokens file saved in ./results-google-deepgram/checkpoint-4500/special_tokens_map.json
# Copy vocab file to ./results-google-deepgram/checkpoint-4500/spiece.model
# Deleting older checkpoint [results-google-deepgram/checkpoint-3000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-deepgram/checkpoint-5000
# Configuration saved in ./results-google-deepgram/checkpoint-5000/config.json
# Model weights saved in ./results-google-deepgram/checkpoint-5000/pytorch_model.bin
# tokenizer config file saved in ./results-google-deepgram/checkpoint-5000/tokenizer_config.json
# Special tokens file saved in ./results-google-deepgram/checkpoint-5000/special_tokens_map.json
# Copy vocab file to ./results-google-deepgram/checkpoint-5000/spiece.model
# Deleting older checkpoint [results-google-deepgram/checkpoint-3500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-deepgram/checkpoint-5500
# Configuration saved in ./results-google-deepgram/checkpoint-5500/config.json
# Model weights saved in ./results-google-deepgram/checkpoint-5500/pytorch_model.bin
# tokenizer config file saved in ./results-google-deepgram/checkpoint-5500/tokenizer_config.json
# Special tokens file saved in ./results-google-deepgram/checkpoint-5500/special_tokens_map.json
# Copy vocab file to ./results-google-deepgram/checkpoint-5500/spiece.model
# Deleting older checkpoint [results-google-deepgram/checkpoint-4000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-deepgram/checkpoint-6000
# Configuration saved in ./results-google-deepgram/checkpoint-6000/config.json
# Model weights saved in ./results-google-deepgram/checkpoint-6000/pytorch_model.bin
# tokenizer config file saved in ./results-google-deepgram/checkpoint-6000/tokenizer_config.json
# Special tokens file saved in ./results-google-deepgram/checkpoint-6000/special_tokens_map.json
# Copy vocab file to ./results-google-deepgram/checkpoint-6000/spiece.model
# Deleting older checkpoint [results-google-deepgram/checkpoint-4500] due to args.save_total_limit
# Saving model checkpoint to ./results-google-deepgram/checkpoint-6500
# Configuration saved in ./results-google-deepgram/checkpoint-6500/config.json
# Model weights saved in ./results-google-deepgram/checkpoint-6500/pytorch_model.bin
# tokenizer config file saved in ./results-google-deepgram/checkpoint-6500/tokenizer_config.json
# Special tokens file saved in ./results-google-deepgram/checkpoint-6500/special_tokens_map.json
# Copy vocab file to ./results-google-deepgram/checkpoint-6500/spiece.model
# Deleting older checkpoint [results-google-deepgram/checkpoint-5000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-deepgram/checkpoint-7000
# Configuration saved in ./results-google-deepgram/checkpoint-7000/config.json
# Model weights saved in ./results-google-deepgram/checkpoint-7000/pytorch_model.bin
# tokenizer config file saved in ./results-google-deepgram/checkpoint-7000/tokenizer_config.json
# Special tokens file saved in ./results-google-deepgram/checkpoint-7000/special_tokens_map.json
# Copy vocab file to ./results-google-deepgram/checkpoint-7000/spiece.model
# Deleting older checkpoint [results-google-deepgram/checkpoint-5500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-deepgram/checkpoint-7500
# Configuration saved in ./results-google-deepgram/checkpoint-7500/config.json
# Model weights saved in ./results-google-deepgram/checkpoint-7500/pytorch_model.bin
# tokenizer config file saved in ./results-google-deepgram/checkpoint-7500/tokenizer_config.json
# Special tokens file saved in ./results-google-deepgram/checkpoint-7500/special_tokens_map.json
# Copy vocab file to ./results-google-deepgram/checkpoint-7500/spiece.model
# Deleting older checkpoint [results-google-deepgram/checkpoint-6000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-deepgram/checkpoint-8000
# Configuration saved in ./results-google-deepgram/checkpoint-8000/config.json
# Model weights saved in ./results-google-deepgram/checkpoint-8000/pytorch_model.bin
# tokenizer config file saved in ./results-google-deepgram/checkpoint-8000/tokenizer_config.json
# Special tokens file saved in ./results-google-deepgram/checkpoint-8000/special_tokens_map.json
# Copy vocab file to ./results-google-deepgram/checkpoint-8000/spiece.model
# Deleting older checkpoint [results-google-deepgram/checkpoint-6500] due to args.save_total_limit
# Saving model checkpoint to ./results-google-deepgram/checkpoint-8500
# Configuration saved in ./results-google-deepgram/checkpoint-8500/config.json
# Model weights saved in ./results-google-deepgram/checkpoint-8500/pytorch_model.bin
# tokenizer config file saved in ./results-google-deepgram/checkpoint-8500/tokenizer_config.json
# Special tokens file saved in ./results-google-deepgram/checkpoint-8500/special_tokens_map.json
# Copy vocab file to ./results-google-deepgram/checkpoint-8500/spiece.model
# Deleting older checkpoint [results-google-deepgram/checkpoint-7000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-deepgram/checkpoint-9000
# Configuration saved in ./results-google-deepgram/checkpoint-9000/config.json
# Model weights saved in ./results-google-deepgram/checkpoint-9000/pytorch_model.bin
# tokenizer config file saved in ./results-google-deepgram/checkpoint-9000/tokenizer_config.json
# Special tokens file saved in ./results-google-deepgram/checkpoint-9000/special_tokens_map.json
# Copy vocab file to ./results-google-deepgram/checkpoint-9000/spiece.model
# Deleting older checkpoint [results-google-deepgram/checkpoint-7500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-deepgram/checkpoint-9500
# Configuration saved in ./results-google-deepgram/checkpoint-9500/config.json
# Model weights saved in ./results-google-deepgram/checkpoint-9500/pytorch_model.bin
# tokenizer config file saved in ./results-google-deepgram/checkpoint-9500/tokenizer_config.json
# Special tokens file saved in ./results-google-deepgram/checkpoint-9500/special_tokens_map.json
# Copy vocab file to ./results-google-deepgram/checkpoint-9500/spiece.model
# Deleting older checkpoint [results-google-deepgram/checkpoint-8000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-deepgram/checkpoint-10000
# Configuration saved in ./results-google-deepgram/checkpoint-10000/config.json
# Model weights saved in ./results-google-deepgram/checkpoint-10000/pytorch_model.bin
# tokenizer config file saved in ./results-google-deepgram/checkpoint-10000/tokenizer_config.json
# Special tokens file saved in ./results-google-deepgram/checkpoint-10000/special_tokens_map.json
# Copy vocab file to ./results-google-deepgram/checkpoint-10000/spiece.model
# Deleting older checkpoint [results-google-deepgram/checkpoint-8500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-deepgram/checkpoint-10500
# Configuration saved in ./results-google-deepgram/checkpoint-10500/config.json
# Model weights saved in ./results-google-deepgram/checkpoint-10500/pytorch_model.bin
# tokenizer config file saved in ./results-google-deepgram/checkpoint-10500/tokenizer_config.json
# Special tokens file saved in ./results-google-deepgram/checkpoint-10500/special_tokens_map.json
# Copy vocab file to ./results-google-deepgram/checkpoint-10500/spiece.model
# Deleting older checkpoint [results-google-deepgram/checkpoint-9000] due to args.save_total_limit
# Saving model checkpoint to ./results-google-deepgram/checkpoint-11000
# Configuration saved in ./results-google-deepgram/checkpoint-11000/config.json
# Model weights saved in ./results-google-deepgram/checkpoint-11000/pytorch_model.bin
# tokenizer config file saved in ./results-google-deepgram/checkpoint-11000/tokenizer_config.json
# Special tokens file saved in ./results-google-deepgram/checkpoint-11000/special_tokens_map.json
# Copy vocab file to ./results-google-deepgram/checkpoint-11000/spiece.model
# Deleting older checkpoint [results-google-deepgram/checkpoint-9500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-deepgram/checkpoint-11500
# Configuration saved in ./results-google-deepgram/checkpoint-11500/config.json
# Model weights saved in ./results-google-deepgram/checkpoint-11500/pytorch_model.bin
# tokenizer config file saved in ./results-google-deepgram/checkpoint-11500/tokenizer_config.json
# Special tokens file saved in ./results-google-deepgram/checkpoint-11500/special_tokens_map.json
# Copy vocab file to ./results-google-deepgram/checkpoint-11500/spiece.model
# Deleting older checkpoint [results-google-deepgram/checkpoint-10000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-deepgram/checkpoint-12000
# Configuration saved in ./results-google-deepgram/checkpoint-12000/config.json
# Model weights saved in ./results-google-deepgram/checkpoint-12000/pytorch_model.bin
# tokenizer config file saved in ./results-google-deepgram/checkpoint-12000/tokenizer_config.json
# Special tokens file saved in ./results-google-deepgram/checkpoint-12000/special_tokens_map.json
# Copy vocab file to ./results-google-deepgram/checkpoint-12000/spiece.model
# Deleting older checkpoint [results-google-deepgram/checkpoint-10500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-deepgram/checkpoint-12500
# Configuration saved in ./results-google-deepgram/checkpoint-12500/config.json
# Model weights saved in ./results-google-deepgram/checkpoint-12500/pytorch_model.bin
# tokenizer config file saved in ./results-google-deepgram/checkpoint-12500/tokenizer_config.json
# Special tokens file saved in ./results-google-deepgram/checkpoint-12500/special_tokens_map.json
# Copy vocab file to ./results-google-deepgram/checkpoint-12500/spiece.model
# Deleting older checkpoint [results-google-deepgram/checkpoint-11000] due to args.save_total_limit
# Saving model checkpoint to ./results-google-deepgram/checkpoint-13000
# Configuration saved in ./results-google-deepgram/checkpoint-13000/config.json
# Model weights saved in ./results-google-deepgram/checkpoint-13000/pytorch_model.bin
# tokenizer config file saved in ./results-google-deepgram/checkpoint-13000/tokenizer_config.json
# Special tokens file saved in ./results-google-deepgram/checkpoint-13000/special_tokens_map.json
# Copy vocab file to ./results-google-deepgram/checkpoint-13000/spiece.model
# Deleting older checkpoint [results-google-deepgram/checkpoint-11500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-deepgram/checkpoint-13500
# Configuration saved in ./results-google-deepgram/checkpoint-13500/config.json
# Model weights saved in ./results-google-deepgram/checkpoint-13500/pytorch_model.bin
# tokenizer config file saved in ./results-google-deepgram/checkpoint-13500/tokenizer_config.json
# Special tokens file saved in ./results-google-deepgram/checkpoint-13500/special_tokens_map.json
# Copy vocab file to ./results-google-deepgram/checkpoint-13500/spiece.model
# Deleting older checkpoint [results-google-deepgram/checkpoint-12000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-deepgram/checkpoint-14000
# Configuration saved in ./results-google-deepgram/checkpoint-14000/config.json
# Model weights saved in ./results-google-deepgram/checkpoint-14000/pytorch_model.bin
# tokenizer config file saved in ./results-google-deepgram/checkpoint-14000/tokenizer_config.json
# Special tokens file saved in ./results-google-deepgram/checkpoint-14000/special_tokens_map.json
# Copy vocab file to ./results-google-deepgram/checkpoint-14000/spiece.model
# Deleting older checkpoint [results-google-deepgram/checkpoint-12500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-deepgram/checkpoint-14500
# Configuration saved in ./results-google-deepgram/checkpoint-14500/config.json
# Model weights saved in ./results-google-deepgram/checkpoint-14500/pytorch_model.bin
# tokenizer config file saved in ./results-google-deepgram/checkpoint-14500/tokenizer_config.json
# Special tokens file saved in ./results-google-deepgram/checkpoint-14500/special_tokens_map.json
# Copy vocab file to ./results-google-deepgram/checkpoint-14500/spiece.model
# Deleting older checkpoint [results-google-deepgram/checkpoint-13000] due to args.save_total_limit
# Saving model checkpoint to ./results-google-deepgram/checkpoint-15000
# Configuration saved in ./results-google-deepgram/checkpoint-15000/config.json
# Model weights saved in ./results-google-deepgram/checkpoint-15000/pytorch_model.bin
# tokenizer config file saved in ./results-google-deepgram/checkpoint-15000/tokenizer_config.json
# Special tokens file saved in ./results-google-deepgram/checkpoint-15000/special_tokens_map.json
# Copy vocab file to ./results-google-deepgram/checkpoint-15000/spiece.model
# Deleting older checkpoint [results-google-deepgram/checkpoint-13500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-deepgram/checkpoint-15500
# Configuration saved in ./results-google-deepgram/checkpoint-15500/config.json
# Model weights saved in ./results-google-deepgram/checkpoint-15500/pytorch_model.bin
# tokenizer config file saved in ./results-google-deepgram/checkpoint-15500/tokenizer_config.json
# Special tokens file saved in ./results-google-deepgram/checkpoint-15500/special_tokens_map.json
# Copy vocab file to ./results-google-deepgram/checkpoint-15500/spiece.model
# Deleting older checkpoint [results-google-deepgram/checkpoint-14000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-deepgram/checkpoint-16000
# Configuration saved in ./results-google-deepgram/checkpoint-16000/config.json
# Model weights saved in ./results-google-deepgram/checkpoint-16000/pytorch_model.bin
# tokenizer config file saved in ./results-google-deepgram/checkpoint-16000/tokenizer_config.json
# Special tokens file saved in ./results-google-deepgram/checkpoint-16000/special_tokens_map.json
# Copy vocab file to ./results-google-deepgram/checkpoint-16000/spiece.model
# Deleting older checkpoint [results-google-deepgram/checkpoint-14500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-deepgram/checkpoint-16500
# Configuration saved in ./results-google-deepgram/checkpoint-16500/config.json
# Model weights saved in ./results-google-deepgram/checkpoint-16500/pytorch_model.bin
# tokenizer config file saved in ./results-google-deepgram/checkpoint-16500/tokenizer_config.json
# Special tokens file saved in ./results-google-deepgram/checkpoint-16500/special_tokens_map.json
# Copy vocab file to ./results-google-deepgram/checkpoint-16500/spiece.model
# Deleting older checkpoint [results-google-deepgram/checkpoint-15000] due to args.save_total_limit
# Saving model checkpoint to ./results-google-deepgram/checkpoint-17000
# Configuration saved in ./results-google-deepgram/checkpoint-17000/config.json
# Model weights saved in ./results-google-deepgram/checkpoint-17000/pytorch_model.bin
# tokenizer config file saved in ./results-google-deepgram/checkpoint-17000/tokenizer_config.json
# Special tokens file saved in ./results-google-deepgram/checkpoint-17000/special_tokens_map.json
# Copy vocab file to ./results-google-deepgram/checkpoint-17000/spiece.model
# Deleting older checkpoint [results-google-deepgram/checkpoint-15500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-deepgram/checkpoint-17500
# Configuration saved in ./results-google-deepgram/checkpoint-17500/config.json
# Model weights saved in ./results-google-deepgram/checkpoint-17500/pytorch_model.bin
# tokenizer config file saved in ./results-google-deepgram/checkpoint-17500/tokenizer_config.json
# Special tokens file saved in ./results-google-deepgram/checkpoint-17500/special_tokens_map.json
# Copy vocab file to ./results-google-deepgram/checkpoint-17500/spiece.model
# Deleting older checkpoint [results-google-deepgram/checkpoint-16000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-deepgram/checkpoint-18000
# Configuration saved in ./results-google-deepgram/checkpoint-18000/config.json
# Model weights saved in ./results-google-deepgram/checkpoint-18000/pytorch_model.bin
# tokenizer config file saved in ./results-google-deepgram/checkpoint-18000/tokenizer_config.json
# Special tokens file saved in ./results-google-deepgram/checkpoint-18000/special_tokens_map.json
# Copy vocab file to ./results-google-deepgram/checkpoint-18000/spiece.model
# Deleting older checkpoint [results-google-deepgram/checkpoint-16500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-deepgram/checkpoint-18500
# Configuration saved in ./results-google-deepgram/checkpoint-18500/config.json
# Model weights saved in ./results-google-deepgram/checkpoint-18500/pytorch_model.bin
# tokenizer config file saved in ./results-google-deepgram/checkpoint-18500/tokenizer_config.json
# Special tokens file saved in ./results-google-deepgram/checkpoint-18500/special_tokens_map.json
# Copy vocab file to ./results-google-deepgram/checkpoint-18500/spiece.model
# Deleting older checkpoint [results-google-deepgram/checkpoint-17000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-deepgram/checkpoint-19000
# Configuration saved in ./results-google-deepgram/checkpoint-19000/config.json
# Model weights saved in ./results-google-deepgram/checkpoint-19000/pytorch_model.bin
# tokenizer config file saved in ./results-google-deepgram/checkpoint-19000/tokenizer_config.json
# Special tokens file saved in ./results-google-deepgram/checkpoint-19000/special_tokens_map.json
# Copy vocab file to ./results-google-deepgram/checkpoint-19000/spiece.model
# Deleting older checkpoint [results-google-deepgram/checkpoint-17500] due to args.save_total_limit
# Saving model checkpoint to ./results-google-deepgram/checkpoint-19500
# Configuration saved in ./results-google-deepgram/checkpoint-19500/config.json
# Model weights saved in ./results-google-deepgram/checkpoint-19500/pytorch_model.bin
# tokenizer config file saved in ./results-google-deepgram/checkpoint-19500/tokenizer_config.json
# Special tokens file saved in ./results-google-deepgram/checkpoint-19500/special_tokens_map.json
# Copy vocab file to ./results-google-deepgram/checkpoint-19500/spiece.model
# Deleting older checkpoint [results-google-deepgram/checkpoint-18000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-deepgram/checkpoint-20000
# Configuration saved in ./results-google-deepgram/checkpoint-20000/config.json
# Model weights saved in ./results-google-deepgram/checkpoint-20000/pytorch_model.bin
# tokenizer config file saved in ./results-google-deepgram/checkpoint-20000/tokenizer_config.json
# Special tokens file saved in ./results-google-deepgram/checkpoint-20000/special_tokens_map.json
# Copy vocab file to ./results-google-deepgram/checkpoint-20000/spiece.model
# Deleting older checkpoint [results-google-deepgram/checkpoint-18500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-deepgram/checkpoint-20500
# Configuration saved in ./results-google-deepgram/checkpoint-20500/config.json
# Model weights saved in ./results-google-deepgram/checkpoint-20500/pytorch_model.bin
# tokenizer config file saved in ./results-google-deepgram/checkpoint-20500/tokenizer_config.json
# Special tokens file saved in ./results-google-deepgram/checkpoint-20500/special_tokens_map.json
# Copy vocab file to ./results-google-deepgram/checkpoint-20500/spiece.model
# Deleting older checkpoint [results-google-deepgram/checkpoint-19000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-deepgram/checkpoint-21000
# Configuration saved in ./results-google-deepgram/checkpoint-21000/config.json
# Model weights saved in ./results-google-deepgram/checkpoint-21000/pytorch_model.bin
# tokenizer config file saved in ./results-google-deepgram/checkpoint-21000/tokenizer_config.json
# Special tokens file saved in ./results-google-deepgram/checkpoint-21000/special_tokens_map.json
# Copy vocab file to ./results-google-deepgram/checkpoint-21000/spiece.model
# Deleting older checkpoint [results-google-deepgram/checkpoint-19500] due to args.save_total_limit
# Saving model checkpoint to ./results-google-deepgram/checkpoint-21500
# Configuration saved in ./results-google-deepgram/checkpoint-21500/config.json
# Model weights saved in ./results-google-deepgram/checkpoint-21500/pytorch_model.bin
# tokenizer config file saved in ./results-google-deepgram/checkpoint-21500/tokenizer_config.json
# Special tokens file saved in ./results-google-deepgram/checkpoint-21500/special_tokens_map.json
# Copy vocab file to ./results-google-deepgram/checkpoint-21500/spiece.model
# Deleting older checkpoint [results-google-deepgram/checkpoint-20000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-deepgram/checkpoint-22000
# Configuration saved in ./results-google-deepgram/checkpoint-22000/config.json
# Model weights saved in ./results-google-deepgram/checkpoint-22000/pytorch_model.bin
# tokenizer config file saved in ./results-google-deepgram/checkpoint-22000/tokenizer_config.json
# Special tokens file saved in ./results-google-deepgram/checkpoint-22000/special_tokens_map.json
# Copy vocab file to ./results-google-deepgram/checkpoint-22000/spiece.model
# Deleting older checkpoint [results-google-deepgram/checkpoint-20500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-deepgram/checkpoint-22500
# Configuration saved in ./results-google-deepgram/checkpoint-22500/config.json
# Model weights saved in ./results-google-deepgram/checkpoint-22500/pytorch_model.bin
# tokenizer config file saved in ./results-google-deepgram/checkpoint-22500/tokenizer_config.json
# Special tokens file saved in ./results-google-deepgram/checkpoint-22500/special_tokens_map.json
# Copy vocab file to ./results-google-deepgram/checkpoint-22500/spiece.model
# Deleting older checkpoint [results-google-deepgram/checkpoint-21000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-deepgram/checkpoint-23000
# Configuration saved in ./results-google-deepgram/checkpoint-23000/config.json
# Model weights saved in ./results-google-deepgram/checkpoint-23000/pytorch_model.bin
# tokenizer config file saved in ./results-google-deepgram/checkpoint-23000/tokenizer_config.json
# Special tokens file saved in ./results-google-deepgram/checkpoint-23000/special_tokens_map.json
# Copy vocab file to ./results-google-deepgram/checkpoint-23000/spiece.model
# Deleting older checkpoint [results-google-deepgram/checkpoint-21500] due to args.save_total_limit
# Saving model checkpoint to ./results-google-deepgram/checkpoint-23500
# Configuration saved in ./results-google-deepgram/checkpoint-23500/config.json
# Model weights saved in ./results-google-deepgram/checkpoint-23500/pytorch_model.bin
# tokenizer config file saved in ./results-google-deepgram/checkpoint-23500/tokenizer_config.json
# Special tokens file saved in ./results-google-deepgram/checkpoint-23500/special_tokens_map.json
# Copy vocab file to ./results-google-deepgram/checkpoint-23500/spiece.model
# Deleting older checkpoint [results-google-deepgram/checkpoint-22000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-deepgram/checkpoint-24000
# Configuration saved in ./results-google-deepgram/checkpoint-24000/config.json
# Model weights saved in ./results-google-deepgram/checkpoint-24000/pytorch_model.bin
# tokenizer config file saved in ./results-google-deepgram/checkpoint-24000/tokenizer_config.json
# Special tokens file saved in ./results-google-deepgram/checkpoint-24000/special_tokens_map.json
# Copy vocab file to ./results-google-deepgram/checkpoint-24000/spiece.model
# Deleting older checkpoint [results-google-deepgram/checkpoint-22500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-deepgram/checkpoint-24500
# Configuration saved in ./results-google-deepgram/checkpoint-24500/config.json
# Model weights saved in ./results-google-deepgram/checkpoint-24500/pytorch_model.bin
# tokenizer config file saved in ./results-google-deepgram/checkpoint-24500/tokenizer_config.json
# Special tokens file saved in ./results-google-deepgram/checkpoint-24500/special_tokens_map.json
# Copy vocab file to ./results-google-deepgram/checkpoint-24500/spiece.model
# Deleting older checkpoint [results-google-deepgram/checkpoint-23000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-deepgram/checkpoint-25000
# Configuration saved in ./results-google-deepgram/checkpoint-25000/config.json
# Model weights saved in ./results-google-deepgram/checkpoint-25000/pytorch_model.bin
# tokenizer config file saved in ./results-google-deepgram/checkpoint-25000/tokenizer_config.json
# Special tokens file saved in ./results-google-deepgram/checkpoint-25000/special_tokens_map.json
# Copy vocab file to ./results-google-deepgram/checkpoint-25000/spiece.model
# Deleting older checkpoint [results-google-deepgram/checkpoint-23500] due to args.save_total_limit
# Saving model checkpoint to ./results-google-deepgram/checkpoint-25500
# Configuration saved in ./results-google-deepgram/checkpoint-25500/config.json
# Model weights saved in ./results-google-deepgram/checkpoint-25500/pytorch_model.bin
# tokenizer config file saved in ./results-google-deepgram/checkpoint-25500/tokenizer_config.json
# Special tokens file saved in ./results-google-deepgram/checkpoint-25500/special_tokens_map.json
# Copy vocab file to ./results-google-deepgram/checkpoint-25500/spiece.model
# Deleting older checkpoint [results-google-deepgram/checkpoint-24000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-deepgram/checkpoint-26000
# Configuration saved in ./results-google-deepgram/checkpoint-26000/config.json
# Model weights saved in ./results-google-deepgram/checkpoint-26000/pytorch_model.bin
# tokenizer config file saved in ./results-google-deepgram/checkpoint-26000/tokenizer_config.json
# Special tokens file saved in ./results-google-deepgram/checkpoint-26000/special_tokens_map.json
# Copy vocab file to ./results-google-deepgram/checkpoint-26000/spiece.model
# Deleting older checkpoint [results-google-deepgram/checkpoint-24500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-deepgram/checkpoint-26500
# Configuration saved in ./results-google-deepgram/checkpoint-26500/config.json
# Model weights saved in ./results-google-deepgram/checkpoint-26500/pytorch_model.bin
# tokenizer config file saved in ./results-google-deepgram/checkpoint-26500/tokenizer_config.json
# Special tokens file saved in ./results-google-deepgram/checkpoint-26500/special_tokens_map.json
# Copy vocab file to ./results-google-deepgram/checkpoint-26500/spiece.model
# Deleting older checkpoint [results-google-deepgram/checkpoint-25000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-deepgram/checkpoint-27000
# Configuration saved in ./results-google-deepgram/checkpoint-27000/config.json
# Model weights saved in ./results-google-deepgram/checkpoint-27000/pytorch_model.bin
# tokenizer config file saved in ./results-google-deepgram/checkpoint-27000/tokenizer_config.json
# Special tokens file saved in ./results-google-deepgram/checkpoint-27000/special_tokens_map.json
# Copy vocab file to ./results-google-deepgram/checkpoint-27000/spiece.model
# Deleting older checkpoint [results-google-deepgram/checkpoint-25500] due to args.save_total_limit
# Saving model checkpoint to ./results-google-deepgram/checkpoint-27500
# Configuration saved in ./results-google-deepgram/checkpoint-27500/config.json
# Model weights saved in ./results-google-deepgram/checkpoint-27500/pytorch_model.bin
# tokenizer config file saved in ./results-google-deepgram/checkpoint-27500/tokenizer_config.json
# Special tokens file saved in ./results-google-deepgram/checkpoint-27500/special_tokens_map.json
# Copy vocab file to ./results-google-deepgram/checkpoint-27500/spiece.model
# Deleting older checkpoint [results-google-deepgram/checkpoint-26000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-deepgram/checkpoint-28000
# Configuration saved in ./results-google-deepgram/checkpoint-28000/config.json
# Model weights saved in ./results-google-deepgram/checkpoint-28000/pytorch_model.bin
# tokenizer config file saved in ./results-google-deepgram/checkpoint-28000/tokenizer_config.json
# Special tokens file saved in ./results-google-deepgram/checkpoint-28000/special_tokens_map.json
# Copy vocab file to ./results-google-deepgram/checkpoint-28000/spiece.model
# Deleting older checkpoint [results-google-deepgram/checkpoint-26500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-deepgram/checkpoint-28500
# Configuration saved in ./results-google-deepgram/checkpoint-28500/config.json
# Model weights saved in ./results-google-deepgram/checkpoint-28500/pytorch_model.bin
# tokenizer config file saved in ./results-google-deepgram/checkpoint-28500/tokenizer_config.json
# Special tokens file saved in ./results-google-deepgram/checkpoint-28500/special_tokens_map.json
# Copy vocab file to ./results-google-deepgram/checkpoint-28500/spiece.model
# Deleting older checkpoint [results-google-deepgram/checkpoint-27000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-deepgram/checkpoint-29000
# Configuration saved in ./results-google-deepgram/checkpoint-29000/config.json
# Model weights saved in ./results-google-deepgram/checkpoint-29000/pytorch_model.bin
# tokenizer config file saved in ./results-google-deepgram/checkpoint-29000/tokenizer_config.json
# Special tokens file saved in ./results-google-deepgram/checkpoint-29000/special_tokens_map.json
# Copy vocab file to ./results-google-deepgram/checkpoint-29000/spiece.model
# Deleting older checkpoint [results-google-deepgram/checkpoint-27500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-deepgram/checkpoint-29500
# Configuration saved in ./results-google-deepgram/checkpoint-29500/config.json
# Model weights saved in ./results-google-deepgram/checkpoint-29500/pytorch_model.bin
# tokenizer config file saved in ./results-google-deepgram/checkpoint-29500/tokenizer_config.json
# Special tokens file saved in ./results-google-deepgram/checkpoint-29500/special_tokens_map.json
# Copy vocab file to ./results-google-deepgram/checkpoint-29500/spiece.model
# Deleting older checkpoint [results-google-deepgram/checkpoint-28000] due to args.save_total_limit
# Saving model checkpoint to ./results-google-deepgram/checkpoint-30000
# Configuration saved in ./results-google-deepgram/checkpoint-30000/config.json
# Model weights saved in ./results-google-deepgram/checkpoint-30000/pytorch_model.bin
# tokenizer config file saved in ./results-google-deepgram/checkpoint-30000/tokenizer_config.json
# Special tokens file saved in ./results-google-deepgram/checkpoint-30000/special_tokens_map.json
# Copy vocab file to ./results-google-deepgram/checkpoint-30000/spiece.model
# Deleting older checkpoint [results-google-deepgram/checkpoint-28500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-deepgram/checkpoint-30500
# Configuration saved in ./results-google-deepgram/checkpoint-30500/config.json
# Model weights saved in ./results-google-deepgram/checkpoint-30500/pytorch_model.bin
# tokenizer config file saved in ./results-google-deepgram/checkpoint-30500/tokenizer_config.json
# Special tokens file saved in ./results-google-deepgram/checkpoint-30500/special_tokens_map.json
# Copy vocab file to ./results-google-deepgram/checkpoint-30500/spiece.model
# Deleting older checkpoint [results-google-deepgram/checkpoint-29000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-deepgram/checkpoint-31000
# ...
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-deepgram/checkpoint-54000
# Configuration saved in ./results-google-deepgram/checkpoint-54000/config.json
# Model weights saved in ./results-google-deepgram/checkpoint-54000/pytorch_model.bin
# tokenizer config file saved in ./results-google-deepgram/checkpoint-54000/tokenizer_config.json
# Special tokens file saved in ./results-google-deepgram/checkpoint-54000/special_tokens_map.json
# Copy vocab file to ./results-google-deepgram/checkpoint-54000/spiece.model
# Deleting older checkpoint [results-google-deepgram/checkpoint-52500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-deepgram/checkpoint-54500
# Configuration saved in ./results-google-deepgram/checkpoint-54500/config.json
# Model weights saved in ./results-google-deepgram/checkpoint-54500/pytorch_model.bin
# tokenizer config file saved in ./results-google-deepgram/checkpoint-54500/tokenizer_config.json
# Special tokens file saved in ./results-google-deepgram/checkpoint-54500/special_tokens_map.json
# Copy vocab file to ./results-google-deepgram/checkpoint-54500/spiece.model
# Deleting older checkpoint [results-google-deepgram/checkpoint-53000] due to args.save_total_limit
# Saving model checkpoint to ./results-google-deepgram/checkpoint-55000
# Configuration saved in ./results-google-deepgram/checkpoint-55000/config.json
# Model weights saved in ./results-google-deepgram/checkpoint-55000/pytorch_model.bin
# tokenizer config file saved in ./results-google-deepgram/checkpoint-55000/tokenizer_config.json
# Special tokens file saved in ./results-google-deepgram/checkpoint-55000/special_tokens_map.json
# Copy vocab file to ./results-google-deepgram/checkpoint-55000/spiece.model
# Deleting older checkpoint [results-google-deepgram/checkpoint-53500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-deepgram/checkpoint-55500
# Configuration saved in ./results-google-deepgram/checkpoint-55500/config.json
# Model weights saved in ./results-google-deepgram/checkpoint-55500/pytorch_model.bin
# tokenizer config file saved in ./results-google-deepgram/checkpoint-55500/tokenizer_config.json
# Special tokens file saved in ./results-google-deepgram/checkpoint-55500/special_tokens_map.json
# Copy vocab file to ./results-google-deepgram/checkpoint-55500/spiece.model
# Deleting older checkpoint [results-google-deepgram/checkpoint-54000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-deepgram/checkpoint-56000
# Configuration saved in ./results-google-deepgram/checkpoint-56000/config.json
# Model weights saved in ./results-google-deepgram/checkpoint-56000/pytorch_model.bin
# tokenizer config file saved in ./results-google-deepgram/checkpoint-56000/tokenizer_config.json
# Special tokens file saved in ./results-google-deepgram/checkpoint-56000/special_tokens_map.json
# Copy vocab file to ./results-google-deepgram/checkpoint-56000/spiece.model
# Deleting older checkpoint [results-google-deepgram/checkpoint-54500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-deepgram/checkpoint-56500
# Configuration saved in ./results-google-deepgram/checkpoint-56500/config.json
# Model weights saved in ./results-google-deepgram/checkpoint-56500/pytorch_model.bin
# tokenizer config file saved in ./results-google-deepgram/checkpoint-56500/tokenizer_config.json
# Special tokens file saved in ./results-google-deepgram/checkpoint-56500/special_tokens_map.json
# Copy vocab file to ./results-google-deepgram/checkpoint-56500/spiece.model
# Deleting older checkpoint [results-google-deepgram/checkpoint-55000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-deepgram/checkpoint-57000
# Configuration saved in ./results-google-deepgram/checkpoint-57000/config.json
# Model weights saved in ./results-google-deepgram/checkpoint-57000/pytorch_model.bin
# tokenizer config file saved in ./results-google-deepgram/checkpoint-57000/tokenizer_config.json
# Special tokens file saved in ./results-google-deepgram/checkpoint-57000/special_tokens_map.json
# Copy vocab file to ./results-google-deepgram/checkpoint-57000/spiece.model
# Deleting older checkpoint [results-google-deepgram/checkpoint-55500] due to args.save_total_limit
# Saving model checkpoint to ./results-google-deepgram/checkpoint-57500
# Configuration saved in ./results-google-deepgram/checkpoint-57500/config.json
# Model weights saved in ./results-google-deepgram/checkpoint-57500/pytorch_model.bin
# tokenizer config file saved in ./results-google-deepgram/checkpoint-57500/tokenizer_config.json
# Special tokens file saved in ./results-google-deepgram/checkpoint-57500/special_tokens_map.json
# Copy vocab file to ./results-google-deepgram/checkpoint-57500/spiece.model
# Deleting older checkpoint [results-google-deepgram/checkpoint-56000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-deepgram/checkpoint-58000
# Configuration saved in ./results-google-deepgram/checkpoint-58000/config.json
# Model weights saved in ./results-google-deepgram/checkpoint-58000/pytorch_model.bin
# tokenizer config file saved in ./results-google-deepgram/checkpoint-58000/tokenizer_config.json
# Special tokens file saved in ./results-google-deepgram/checkpoint-58000/special_tokens_map.json
# Copy vocab file to ./results-google-deepgram/checkpoint-58000/spiece.model
# Deleting older checkpoint [results-google-deepgram/checkpoint-56500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-deepgram/checkpoint-58500
# Configuration saved in ./results-google-deepgram/checkpoint-58500/config.json
# Model weights saved in ./results-google-deepgram/checkpoint-58500/pytorch_model.bin
# tokenizer config file saved in ./results-google-deepgram/checkpoint-58500/tokenizer_config.json
# Special tokens file saved in ./results-google-deepgram/checkpoint-58500/special_tokens_map.json
# Copy vocab file to ./results-google-deepgram/checkpoint-58500/spiece.model
# Deleting older checkpoint [results-google-deepgram/checkpoint-57000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-deepgram/checkpoint-59000
# Configuration saved in ./results-google-deepgram/checkpoint-59000/config.json
# Model weights saved in ./results-google-deepgram/checkpoint-59000/pytorch_model.bin
# tokenizer config file saved in ./results-google-deepgram/checkpoint-59000/tokenizer_config.json
# Special tokens file saved in ./results-google-deepgram/checkpoint-59000/special_tokens_map.json
# Copy vocab file to ./results-google-deepgram/checkpoint-59000/spiece.model
# Deleting older checkpoint [results-google-deepgram/checkpoint-57500] due to args.save_total_limit
# Saving model checkpoint to ./results-google-deepgram/checkpoint-59500
# Configuration saved in ./results-google-deepgram/checkpoint-59500/config.json
# Model weights saved in ./results-google-deepgram/checkpoint-59500/pytorch_model.bin
# tokenizer config file saved in ./results-google-deepgram/checkpoint-59500/tokenizer_config.json
# Special tokens file saved in ./results-google-deepgram/checkpoint-59500/special_tokens_map.json
# Copy vocab file to ./results-google-deepgram/checkpoint-59500/spiece.model
# Deleting older checkpoint [results-google-deepgram/checkpoint-58000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-deepgram/checkpoint-60000
# Configuration saved in ./results-google-deepgram/checkpoint-60000/config.json
# Model weights saved in ./results-google-deepgram/checkpoint-60000/pytorch_model.bin
# tokenizer config file saved in ./results-google-deepgram/checkpoint-60000/tokenizer_config.json
# Special tokens file saved in ./results-google-deepgram/checkpoint-60000/special_tokens_map.json
# Copy vocab file to ./results-google-deepgram/checkpoint-60000/spiece.model
# Deleting older checkpoint [results-google-deepgram/checkpoint-58500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-deepgram/checkpoint-60500
# Configuration saved in ./results-google-deepgram/checkpoint-60500/config.json
# Model weights saved in ./results-google-deepgram/checkpoint-60500/pytorch_model.bin
# tokenizer config file saved in ./results-google-deepgram/checkpoint-60500/tokenizer_config.json
# Special tokens file saved in ./results-google-deepgram/checkpoint-60500/special_tokens_map.json
# Copy vocab file to ./results-google-deepgram/checkpoint-60500/spiece.model
# Deleting older checkpoint [results-google-deepgram/checkpoint-59000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-deepgram/checkpoint-61000
# Configuration saved in ./results-google-deepgram/checkpoint-61000/config.json
# Model weights saved in ./results-google-deepgram/checkpoint-61000/pytorch_model.bin
# tokenizer config file saved in ./results-google-deepgram/checkpoint-61000/tokenizer_config.json
# Special tokens file saved in ./results-google-deepgram/checkpoint-61000/special_tokens_map.json
# Copy vocab file to ./results-google-deepgram/checkpoint-61000/spiece.model
# Deleting older checkpoint [results-google-deepgram/checkpoint-59500] due to args.save_total_limit
# Saving model checkpoint to ./results-google-deepgram/checkpoint-61500
# Configuration saved in ./results-google-deepgram/checkpoint-61500/config.json
# Model weights saved in ./results-google-deepgram/checkpoint-61500/pytorch_model.bin
# tokenizer config file saved in ./results-google-deepgram/checkpoint-61500/tokenizer_config.json
# Special tokens file saved in ./results-google-deepgram/checkpoint-61500/special_tokens_map.json
# Copy vocab file to ./results-google-deepgram/checkpoint-61500/spiece.model
# Deleting older checkpoint [results-google-deepgram/checkpoint-60000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-deepgram/checkpoint-62000
# Configuration saved in ./results-google-deepgram/checkpoint-62000/config.json
# Model weights saved in ./results-google-deepgram/checkpoint-62000/pytorch_model.bin
# tokenizer config file saved in ./results-google-deepgram/checkpoint-62000/tokenizer_config.json
# Special tokens file saved in ./results-google-deepgram/checkpoint-62000/special_tokens_map.json
# Copy vocab file to ./results-google-deepgram/checkpoint-62000/spiece.model
# Deleting older checkpoint [results-google-deepgram/checkpoint-60500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-deepgram/checkpoint-62500
# Configuration saved in ./results-google-deepgram/checkpoint-62500/config.json
# Model weights saved in ./results-google-deepgram/checkpoint-62500/pytorch_model.bin
# tokenizer config file saved in ./results-google-deepgram/checkpoint-62500/tokenizer_config.json
# Special tokens file saved in ./results-google-deepgram/checkpoint-62500/special_tokens_map.json
# Copy vocab file to ./results-google-deepgram/checkpoint-62500/spiece.model
# Deleting older checkpoint [results-google-deepgram/checkpoint-61000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-deepgram/checkpoint-63000
# Configuration saved in ./results-google-deepgram/checkpoint-63000/config.json
# Model weights saved in ./results-google-deepgram/checkpoint-63000/pytorch_model.bin
# tokenizer config file saved in ./results-google-deepgram/checkpoint-63000/tokenizer_config.json
# Special tokens file saved in ./results-google-deepgram/checkpoint-63000/special_tokens_map.json
# Copy vocab file to ./results-google-deepgram/checkpoint-63000/spiece.model
# Deleting older checkpoint [results-google-deepgram/checkpoint-61500] due to args.save_total_limit
# Saving model checkpoint to ./results-google-deepgram/checkpoint-63500
# Configuration saved in ./results-google-deepgram/checkpoint-63500/config.json
# Model weights saved in ./results-google-deepgram/checkpoint-63500/pytorch_model.bin
# tokenizer config file saved in ./results-google-deepgram/checkpoint-63500/tokenizer_config.json
# Special tokens file saved in ./results-google-deepgram/checkpoint-63500/special_tokens_map.json
# Copy vocab file to ./results-google-deepgram/checkpoint-63500/spiece.model
# Deleting older checkpoint [results-google-deepgram/checkpoint-62000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-deepgram/checkpoint-64000
# Configuration saved in ./results-google-deepgram/checkpoint-64000/config.json
# Model weights saved in ./results-google-deepgram/checkpoint-64000/pytorch_model.bin
# tokenizer config file saved in ./results-google-deepgram/checkpoint-64000/tokenizer_config.json
# Special tokens file saved in ./results-google-deepgram/checkpoint-64000/special_tokens_map.json
# Copy vocab file to ./results-google-deepgram/checkpoint-64000/spiece.model
# Deleting older checkpoint [results-google-deepgram/checkpoint-62500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-deepgram/checkpoint-64500
# Configuration saved in ./results-google-deepgram/checkpoint-64500/config.json
# Model weights saved in ./results-google-deepgram/checkpoint-64500/pytorch_model.bin
# tokenizer config file saved in ./results-google-deepgram/checkpoint-64500/tokenizer_config.json
# Special tokens file saved in ./results-google-deepgram/checkpoint-64500/special_tokens_map.json
# Copy vocab file to ./results-google-deepgram/checkpoint-64500/spiece.model
# Deleting older checkpoint [results-google-deepgram/checkpoint-63000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-deepgram/checkpoint-65000
# Configuration saved in ./results-google-deepgram/checkpoint-65000/config.json
# Model weights saved in ./results-google-deepgram/checkpoint-65000/pytorch_model.bin
# tokenizer config file saved in ./results-google-deepgram/checkpoint-65000/tokenizer_config.json
# Special tokens file saved in ./results-google-deepgram/checkpoint-65000/special_tokens_map.json
# Copy vocab file to ./results-google-deepgram/checkpoint-65000/spiece.model
# Deleting older checkpoint [results-google-deepgram/checkpoint-63500] due to args.save_total_limit
# Saving model checkpoint to ./results-google-deepgram/checkpoint-65500
# Configuration saved in ./results-google-deepgram/checkpoint-65500/config.json
# Model weights saved in ./results-google-deepgram/checkpoint-65500/pytorch_model.bin
# tokenizer config file saved in ./results-google-deepgram/checkpoint-65500/tokenizer_config.json
# Special tokens file saved in ./results-google-deepgram/checkpoint-65500/special_tokens_map.json
# Copy vocab file to ./results-google-deepgram/checkpoint-65500/spiece.model
# Deleting older checkpoint [results-google-deepgram/checkpoint-64000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=65500, training_loss=0.025614049649420587, metrics={'train_runtime': 24760.7764, 'train_samples_per_second': 42.313, 'train_steps_per_second': 2.645, 'total_flos': 8.8623503376384e+16, 'train_loss': 0.025614049649420587, 'epoch': 100.0})

# %%
import torch

device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")

results = []

for batch in tokenized_datasets_valid:
  y_pred = model.generate(torch.tensor([batch['input_ids']]).to(device))

  for i in range(len(y_pred)):
    results.append({
      'input': tokenizer.decode(batch['input_ids'], skip_special_tokens=True),
      'output': tokenizer.decode(y_pred[i], skip_special_tokens=True),
      'label': tokenizer.decode(batch['labels'], skip_special_tokens=True),
    })

results_df = pd.DataFrame(results)
results_df.to_csv(DS_DIR + 'google-deepgram-results.csv')
