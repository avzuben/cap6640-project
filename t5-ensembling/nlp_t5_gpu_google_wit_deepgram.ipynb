# %%
# !pip install transformers[sentencepiece]
# Out:
# Requirement already satisfied: transformers[sentencepiece] in /usr/local/lib/python3.7/dist-packages (4.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from transformers[sentencepiece]) (0.5.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers[sentencepiece]) (1.21.6)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers[sentencepiece]) (4.64.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers[sentencepiece]) (2019.12.20)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers[sentencepiece]) (0.0.49)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers[sentencepiece]) (21.3)
# Requirement already satisfied: tokenizers!=0.11.3,<0.13,>=0.11.1 in /usr/local/lib/python3.7/dist-packages (from transformers[sentencepiece]) (0.12.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers[sentencepiece]) (6.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers[sentencepiece]) (4.11.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers[sentencepiece]) (3.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers[sentencepiece]) (2.23.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.7/dist-packages (from transformers[sentencepiece]) (3.17.3)
# Requirement already satisfied: sentencepiece!=0.1.92,>=0.1.91 in /usr/local/lib/python3.7/dist-packages (from transformers[sentencepiece]) (0.1.96)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers[sentencepiece]) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers[sentencepiece]) (3.0.8)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers[sentencepiece]) (3.8.0)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.7/dist-packages (from protobuf->transformers[sentencepiece]) (1.15.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers[sentencepiece]) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers[sentencepiece]) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers[sentencepiece]) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers[sentencepiece]) (2021.10.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers[sentencepiece]) (1.1.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers[sentencepiece]) (7.1.2)

# %%
# !pip install datasets
# Out:
# Requirement already satisfied: datasets in /usr/local/lib/python3.7/dist-packages (2.1.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from datasets) (4.11.3)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (2022.3.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.7/dist-packages (from datasets) (0.70.12.2)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.7/dist-packages (from datasets) (4.64.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from datasets) (21.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (2.23.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from datasets) (1.21.6)
# Requirement already satisfied: responses<0.19 in /usr/local/lib/python3.7/dist-packages (from datasets) (0.18.0)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.7/dist-packages (from datasets) (3.0.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from datasets) (1.3.5)
# Requirement already satisfied: pyarrow>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (0.5.1)
# Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from datasets) (0.3.4)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.7/dist-packages (from datasets) (3.8.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (4.1.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (3.6.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->datasets) (3.0.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (2.10)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (6.0.2)
# Requirement already satisfied: asynctest==0.13.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (0.13.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (21.4.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.7.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.3.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (2.0.12)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->datasets) (3.8.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2022.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->datasets) (1.15.0)

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
from transformers import AutoTokenizer
from transformers import AutoModelForSeq2SeqLM, Seq2SeqTrainingArguments, Seq2SeqTrainer

tokenizer = AutoTokenizer.from_pretrained("t5-small")
model = AutoModelForSeq2SeqLM.from_pretrained("t5-small")

# %%
import numpy as np
import pandas as pd

# DS_DIR = './'
DS_DIR = '/content/gdrive/My Drive/'
label = 'text1'
models = ['google', 'wit', 'deepgram']


def load_data(model):
    df = pd.read_csv(DS_DIR + 'ljs-data.csv')
    train_df, valid_df = np.split(df.sample(frac=1, random_state=42), [int(.8 * len(df))])
    errors_train = train_df['google'].isna().values | train_df['wit'].isna().values | train_df['deepgram'].isna().values
    y_train = train_df[label].values
    X_train = train_df[model].values
    errors_valid = valid_df['google'].isna().values | valid_df['wit'].isna().values | valid_df['deepgram'].isna().values
    y_valid = valid_df[label].values
    X_valid = valid_df[model].values
    return X_train[~errors_train], y_train[~errors_train], X_valid[~errors_valid], y_valid[~errors_valid]

# %%
X1_train, y1_train, X1_valid, y1_valid = load_data('google')
X2_train, y2_train, X2_valid, y2_valid = load_data('wit')
X3_train, y3_train, X3_valid, y3_valid = load_data('deepgram')

# %%
from datasets import Dataset

df_train = pd.DataFrame({"text1": X1_train, "text2": X2_train, "text3": X3_train, "labels": y1_train})
dataset_train = Dataset.from_pandas(df_train)

df_valid = pd.DataFrame({"text1": X1_valid, "text2": X2_valid, "text3": X3_valid, "labels": y1_valid})
dataset_valid = Dataset.from_pandas(df_valid)

# %%
prefix = "merge sentence1: "
infix1 = " sentence2: "
infix2 = " sentence3: "

def preprocess_function(examples):
    inputs = [prefix + examples["text1"][i] + infix1 + examples["text2"][i] + infix2 + examples["text3"][i] for i in range(len(examples["text1"]))]
    model_inputs = tokenizer(inputs, padding="max_length", max_length=480, truncation=True)

    with tokenizer.as_target_tokenizer():
        labels = tokenizer(examples['labels'], padding="max_length", max_length=160, truncation=True)

    # model_inputs["input_ids"] = model_inputs["input_ids"].squeeze(0)
    # model_inputs["attention_mask"] = model_inputs["attention_mask"].squeeze(0)
    model_inputs["labels"] = labels["input_ids"] #.squeeze(0)

    return model_inputs

tokenized_datasets_train = dataset_train.map(preprocess_function, batched=True)
tokenized_datasets_valid = dataset_valid.map(preprocess_function, batched=True)
# Out:
#   0%|          | 0/11 [00:00<?, ?ba/s]
#   0%|          | 0/3 [00:00<?, ?ba/s]

# %%
tokenized_datasets_train = tokenized_datasets_train.remove_columns(["text1", "text2", "text3"])
tokenized_datasets_valid = tokenized_datasets_valid.remove_columns(["text1", "text2", "text3"])
# tokenized_datasets.set_format("torch")
tokenized_datasets_train
# Out:
# Dataset({
#     features: ['labels', 'input_ids', 'attention_mask'],
#     num_rows: 10477
# })

# %%
from transformers import DataCollatorForSeq2Seq

data_collator = DataCollatorForSeq2Seq(tokenizer=tokenizer, model=model)

# %%
training_args = Seq2SeqTrainingArguments(
    output_dir="./results-google-wit-deepgram",
    evaluation_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    weight_decay=0.01,
    save_total_limit=3,
    num_train_epochs=100,
    fp16=True,
)

# %%
trainer = Seq2SeqTrainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_datasets_train,
    eval_dataset=tokenized_datasets_valid,
    tokenizer=tokenizer,
    data_collator=data_collator,
)
# Out:
# Using amp half precision backend

# %%
trainer.train()
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:309: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 10477
#   Num Epochs = 100
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 16
#   Gradient Accumulation steps = 1
#   Total optimization steps = 65500
#     <div>
#
#       <progress value='65500' max='65500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [65500/65500 6:55:54, Epoch 100/100]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.600700</td>
#       <td>0.078829</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.095400</td>
#       <td>0.067553</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.081800</td>
#       <td>0.062423</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.071700</td>
#       <td>0.059222</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.068800</td>
#       <td>0.056562</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.066000</td>
#       <td>0.054218</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.061400</td>
#       <td>0.053087</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.059300</td>
#       <td>0.051301</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.057500</td>
#       <td>0.050225</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.054700</td>
#       <td>0.049545</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.053100</td>
#       <td>0.049054</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.052200</td>
#       <td>0.047947</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.050400</td>
#       <td>0.047551</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.049100</td>
#       <td>0.047186</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.048100</td>
#       <td>0.046368</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.047000</td>
#       <td>0.046005</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.045500</td>
#       <td>0.045718</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.045300</td>
#       <td>0.045398</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.043700</td>
#       <td>0.045295</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.043100</td>
#       <td>0.044930</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.042100</td>
#       <td>0.044643</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.041900</td>
#       <td>0.044696</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.040700</td>
#       <td>0.044138</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.039700</td>
#       <td>0.044216</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.039900</td>
#       <td>0.044074</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.039000</td>
#       <td>0.043963</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.038200</td>
#       <td>0.043738</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.037500</td>
#       <td>0.043663</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.037000</td>
#       <td>0.043775</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.036500</td>
#       <td>0.043690</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.035100</td>
#       <td>0.043446</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.035800</td>
#       <td>0.043446</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.034900</td>
#       <td>0.043463</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.034300</td>
#       <td>0.043528</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.033800</td>
#       <td>0.043254</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.033000</td>
#       <td>0.043313</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.032600</td>
#       <td>0.043312</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.032500</td>
#       <td>0.043525</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.031800</td>
#       <td>0.043399</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.031400</td>
#       <td>0.043315</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.032300</td>
#       <td>0.043254</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.031000</td>
#       <td>0.043249</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.030700</td>
#       <td>0.043340</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>0.030300</td>
#       <td>0.043122</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.030600</td>
#       <td>0.043259</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.029600</td>
#       <td>0.043257</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>0.029100</td>
#       <td>0.043437</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.029700</td>
#       <td>0.043517</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.028300</td>
#       <td>0.043680</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.028400</td>
#       <td>0.043695</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>0.028400</td>
#       <td>0.043875</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>0.027500</td>
#       <td>0.043556</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>0.028000</td>
#       <td>0.043843</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>0.027200</td>
#       <td>0.043927</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>0.027400</td>
#       <td>0.043812</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>0.026600</td>
#       <td>0.043883</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>0.026500</td>
#       <td>0.044084</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>0.026500</td>
#       <td>0.044032</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>0.026200</td>
#       <td>0.043929</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.026000</td>
#       <td>0.044109</td>
#     </tr>
#     <tr>
#       <td>61</td>
#       <td>0.025900</td>
#       <td>0.044173</td>
#     </tr>
#     <tr>
#       <td>62</td>
#       <td>0.025700</td>
#       <td>0.044323</td>
#     </tr>
#     <tr>
#       <td>63</td>
#       <td>0.024800</td>
#       <td>0.044322</td>
#     </tr>
#     <tr>
#       <td>64</td>
#       <td>0.025600</td>
#       <td>0.044309</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>0.025400</td>
#       <td>0.044118</td>
#     </tr>
#     <tr>
#       <td>66</td>
#       <td>0.025000</td>
#       <td>0.044255</td>
#     </tr>
#     <tr>
#       <td>67</td>
#       <td>0.024600</td>
#       <td>0.044448</td>
#     </tr>
#     <tr>
#       <td>68</td>
#       <td>0.025000</td>
#       <td>0.044389</td>
#     </tr>
#     <tr>
#       <td>69</td>
#       <td>0.024500</td>
#       <td>0.044586</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.024300</td>
#       <td>0.044559</td>
#     </tr>
#     <tr>
#       <td>71</td>
#       <td>0.024400</td>
#       <td>0.044695</td>
#     </tr>
#     <tr>
#       <td>72</td>
#       <td>0.024000</td>
#       <td>0.044544</td>
#     </tr>
#     <tr>
#       <td>73</td>
#       <td>0.024100</td>
#       <td>0.044549</td>
#     </tr>
#     <tr>
#       <td>74</td>
#       <td>0.023900</td>
#       <td>0.044652</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>0.023900</td>
#       <td>0.044802</td>
#     </tr>
#     <tr>
#       <td>76</td>
#       <td>0.023300</td>
#       <td>0.044644</td>
#     </tr>
#     <tr>
#       <td>77</td>
#       <td>0.023700</td>
#       <td>0.044762</td>
#     </tr>
#     <tr>
#       <td>78</td>
#       <td>0.023600</td>
#       <td>0.044917</td>
#     </tr>
#     <tr>
#       <td>79</td>
#       <td>0.023300</td>
#       <td>0.044836</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.022800</td>
#       <td>0.044907</td>
#     </tr>
#     <tr>
#       <td>81</td>
#       <td>0.023400</td>
#       <td>0.044897</td>
#     </tr>
#     <tr>
#       <td>82</td>
#       <td>0.022800</td>
#       <td>0.045052</td>
#     </tr>
#     <tr>
#       <td>83</td>
#       <td>0.022800</td>
#       <td>0.045079</td>
#     </tr>
#     <tr>
#       <td>84</td>
#       <td>0.022800</td>
#       <td>0.045044</td>
#     </tr>
#     <tr>
#       <td>85</td>
#       <td>0.023000</td>
#       <td>0.045139</td>
#     </tr>
#     <tr>
#       <td>86</td>
#       <td>0.021600</td>
#       <td>0.045120</td>
#     </tr>
#     <tr>
#       <td>87</td>
#       <td>0.022800</td>
#       <td>0.045063</td>
#     </tr>
#     <tr>
#       <td>88</td>
#       <td>0.022600</td>
#       <td>0.045137</td>
#     </tr>
#     <tr>
#       <td>89</td>
#       <td>0.022200</td>
#       <td>0.045200</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>0.022400</td>
#       <td>0.04
# Saving model checkpoint to ./results-google-wit-deepgram/checkpoint-500
# Configuration saved in ./results-google-wit-deepgram/checkpoint-500/config.json
# Model weights saved in ./results-google-wit-deepgram/checkpoint-500/pytorch_model.bin
# tokenizer config file saved in ./results-google-wit-deepgram/checkpoint-500/tokenizer_config.json
# Special tokens file saved in ./results-google-wit-deepgram/checkpoint-500/special_tokens_map.json
# Copy vocab file to ./results-google-wit-deepgram/checkpoint-500/spiece.model
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-wit-deepgram/checkpoint-1000
# Configuration saved in ./results-google-wit-deepgram/checkpoint-1000/config.json
# Model weights saved in ./results-google-wit-deepgram/checkpoint-1000/pytorch_model.bin
# tokenizer config file saved in ./results-google-wit-deepgram/checkpoint-1000/tokenizer_config.json
# Special tokens file saved in ./results-google-wit-deepgram/checkpoint-1000/special_tokens_map.json
# Copy vocab file to ./results-google-wit-deepgram/checkpoint-1000/spiece.model
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-wit-deepgram/checkpoint-1500
# Configuration saved in ./results-google-wit-deepgram/checkpoint-1500/config.json
# Model weights saved in ./results-google-wit-deepgram/checkpoint-1500/pytorch_model.bin
# tokenizer config file saved in ./results-google-wit-deepgram/checkpoint-1500/tokenizer_config.json
# Special tokens file saved in ./results-google-wit-deepgram/checkpoint-1500/special_tokens_map.json
# Copy vocab file to ./results-google-wit-deepgram/checkpoint-1500/spiece.model
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-wit-deepgram/checkpoint-2000
# Configuration saved in ./results-google-wit-deepgram/checkpoint-2000/config.json
# Model weights saved in ./results-google-wit-deepgram/checkpoint-2000/pytorch_model.bin
# tokenizer config file saved in ./results-google-wit-deepgram/checkpoint-2000/tokenizer_config.json
# Special tokens file saved in ./results-google-wit-deepgram/checkpoint-2000/special_tokens_map.json
# Copy vocab file to ./results-google-wit-deepgram/checkpoint-2000/spiece.model
# Deleting older checkpoint [results-google-wit-deepgram/checkpoint-500] due to args.save_total_limit
# Saving model checkpoint to ./results-google-wit-deepgram/checkpoint-2500
# Configuration saved in ./results-google-wit-deepgram/checkpoint-2500/config.json
# Model weights saved in ./results-google-wit-deepgram/checkpoint-2500/pytorch_model.bin
# tokenizer config file saved in ./results-google-wit-deepgram/checkpoint-2500/tokenizer_config.json
# Special tokens file saved in ./results-google-wit-deepgram/checkpoint-2500/special_tokens_map.json
# Copy vocab file to ./results-google-wit-deepgram/checkpoint-2500/spiece.model
# Deleting older checkpoint [results-google-wit-deepgram/checkpoint-1000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-wit-deepgram/checkpoint-3000
# Configuration saved in ./results-google-wit-deepgram/checkpoint-3000/config.json
# Model weights saved in ./results-google-wit-deepgram/checkpoint-3000/pytorch_model.bin
# tokenizer config file saved in ./results-google-wit-deepgram/checkpoint-3000/tokenizer_config.json
# Special tokens file saved in ./results-google-wit-deepgram/checkpoint-3000/special_tokens_map.json
# Copy vocab file to ./results-google-wit-deepgram/checkpoint-3000/spiece.model
# Deleting older checkpoint [results-google-wit-deepgram/checkpoint-1500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-wit-deepgram/checkpoint-3500
# Configuration saved in ./results-google-wit-deepgram/checkpoint-3500/config.json
# Model weights saved in ./results-google-wit-deepgram/checkpoint-3500/pytorch_model.bin
# tokenizer config file saved in ./results-google-wit-deepgram/checkpoint-3500/tokenizer_config.json
# Special tokens file saved in ./results-google-wit-deepgram/checkpoint-3500/special_tokens_map.json
# Copy vocab file to ./results-google-wit-deepgram/checkpoint-3500/spiece.model
# Deleting older checkpoint [results-google-wit-deepgram/checkpoint-2000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-wit-deepgram/checkpoint-4000
# Configuration saved in ./results-google-wit-deepgram/checkpoint-4000/config.json
# Model weights saved in ./results-google-wit-deepgram/checkpoint-4000/pytorch_model.bin
# tokenizer config file saved in ./results-google-wit-deepgram/checkpoint-4000/tokenizer_config.json
# Special tokens file saved in ./results-google-wit-deepgram/checkpoint-4000/special_tokens_map.json
# Copy vocab file to ./results-google-wit-deepgram/checkpoint-4000/spiece.model
# Deleting older checkpoint [results-google-wit-deepgram/checkpoint-2500] due to args.save_total_limit
# Saving model checkpoint to ./results-google-wit-deepgram/checkpoint-4500
# Configuration saved in ./results-google-wit-deepgram/checkpoint-4500/config.json
# Model weights saved in ./results-google-wit-deepgram/checkpoint-4500/pytorch_model.bin
# tokenizer config file saved in ./results-google-wit-deepgram/checkpoint-4500/tokenizer_config.json
# Special tokens file saved in ./results-google-wit-deepgram/checkpoint-4500/special_tokens_map.json
# Copy vocab file to ./results-google-wit-deepgram/checkpoint-4500/spiece.model
# Deleting older checkpoint [results-google-wit-deepgram/checkpoint-3000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-wit-deepgram/checkpoint-5000
# Configuration saved in ./results-google-wit-deepgram/checkpoint-5000/config.json
# Model weights saved in ./results-google-wit-deepgram/checkpoint-5000/pytorch_model.bin
# tokenizer config file saved in ./results-google-wit-deepgram/checkpoint-5000/tokenizer_config.json
# Special tokens file saved in ./results-google-wit-deepgram/checkpoint-5000/special_tokens_map.json
# Copy vocab file to ./results-google-wit-deepgram/checkpoint-5000/spiece.model
# Deleting older checkpoint [results-google-wit-deepgram/checkpoint-3500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-wit-deepgram/checkpoint-5500
# Configuration saved in ./results-google-wit-deepgram/checkpoint-5500/config.json
# Model weights saved in ./results-google-wit-deepgram/checkpoint-5500/pytorch_model.bin
# tokenizer config file saved in ./results-google-wit-deepgram/checkpoint-5500/tokenizer_config.json
# Special tokens file saved in ./results-google-wit-deepgram/checkpoint-5500/special_tokens_map.json
# Copy vocab file to ./results-google-wit-deepgram/checkpoint-5500/spiece.model
# Deleting older checkpoint [results-google-wit-deepgram/checkpoint-4000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-wit-deepgram/checkpoint-6000
# Configuration saved in ./results-google-wit-deepgram/checkpoint-6000/config.json
# Model weights saved in ./results-google-wit-deepgram/checkpoint-6000/pytorch_model.bin
# tokenizer config file saved in ./results-google-wit-deepgram/checkpoint-6000/tokenizer_config.json
# Special tokens file saved in ./results-google-wit-deepgram/checkpoint-6000/special_tokens_map.json
# Copy vocab file to ./results-google-wit-deepgram/checkpoint-6000/spiece.model
# Deleting older checkpoint [results-google-wit-deepgram/checkpoint-4500] due to args.save_total_limit
# Saving model checkpoint to ./results-google-wit-deepgram/checkpoint-6500
# Configuration saved in ./results-google-wit-deepgram/checkpoint-6500/config.json
# Model weights saved in ./results-google-wit-deepgram/checkpoint-6500/pytorch_model.bin
# tokenizer config file saved in ./results-google-wit-deepgram/checkpoint-6500/tokenizer_config.json
# Special tokens file saved in ./results-google-wit-deepgram/checkpoint-6500/special_tokens_map.json
# Copy vocab file to ./results-google-wit-deepgram/checkpoint-6500/spiece.model
# Deleting older checkpoint [results-google-wit-deepgram/checkpoint-5000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-wit-deepgram/checkpoint-7000
# Configuration saved in ./results-google-wit-deepgram/checkpoint-7000/config.json
# Model weights saved in ./results-google-wit-deepgram/checkpoint-7000/pytorch_model.bin
# tokenizer config file saved in ./results-google-wit-deepgram/checkpoint-7000/tokenizer_config.json
# Special tokens file saved in ./results-google-wit-deepgram/checkpoint-7000/special_tokens_map.json
# Copy vocab file to ./results-google-wit-deepgram/checkpoint-7000/spiece.model
# Deleting older checkpoint [results-google-wit-deepgram/checkpoint-5500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-wit-deepgram/checkpoint-7500
# Configuration saved in ./results-google-wit-deepgram/checkpoint-7500/config.json
# Model weights saved in ./results-google-wit-deepgram/checkpoint-7500/pytorch_model.bin
# tokenizer config file saved in ./results-google-wit-deepgram/checkpoint-7500/tokenizer_config.json
# Special tokens file saved in ./results-google-wit-deepgram/checkpoint-7500/special_tokens_map.json
# Copy vocab file to ./results-google-wit-deepgram/checkpoint-7500/spiece.model
# Deleting older checkpoint [results-google-wit-deepgram/checkpoint-6000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-wit-deepgram/checkpoint-8000
# Configuration saved in ./results-google-wit-deepgram/checkpoint-8000/config.json
# Model weights saved in ./results-google-wit-deepgram/checkpoint-8000/pytorch_model.bin
# tokenizer config file saved in ./results-google-wit-deepgram/checkpoint-8000/tokenizer_config.json
# Special tokens file saved in ./results-google-wit-deepgram/checkpoint-8000/special_tokens_map.json
# Copy vocab file to ./results-google-wit-deepgram/checkpoint-8000/spiece.model
# Deleting older checkpoint [results-google-wit-deepgram/checkpoint-6500] due to args.save_total_limit
# Saving model checkpoint to ./results-google-wit-deepgram/checkpoint-8500
# Configuration saved in ./results-google-wit-deepgram/checkpoint-8500/config.json
# Model weights saved in ./results-google-wit-deepgram/checkpoint-8500/pytorch_model.bin
# tokenizer config file saved in ./results-google-wit-deepgram/checkpoint-8500/tokenizer_config.json
# Special tokens file saved in ./results-google-wit-deepgram/checkpoint-8500/special_tokens_map.json
# Copy vocab file to ./results-google-wit-deepgram/checkpoint-8500/spiece.model
# Deleting older checkpoint [results-google-wit-deepgram/checkpoint-7000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-wit-deepgram/checkpoint-9000
# Configuration saved in ./results-google-wit-deepgram/checkpoint-9000/config.json
# Model weights saved in ./results-google-wit-deepgram/checkpoint-9000/pytorch_model.bin
# tokenizer config file saved in ./results-google-wit-deepgram/checkpoint-9000/tokenizer_config.json
# Special tokens file saved in ./results-google-wit-deepgram/checkpoint-9000/special_tokens_map.json
# Copy vocab file to ./results-google-wit-deepgram/checkpoint-9000/spiece.model
# Deleting older checkpoint [results-google-wit-deepgram/checkpoint-7500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-wit-deepgram/checkpoint-9500
# Configuration saved in ./results-google-wit-deepgram/checkpoint-9500/config.json
# Model weights saved in ./results-google-wit-deepgram/checkpoint-9500/pytorch_model.bin
# tokenizer config file saved in ./results-google-wit-deepgram/checkpoint-9500/tokenizer_config.json
# Special tokens file saved in ./results-google-wit-deepgram/checkpoint-9500/special_tokens_map.json
# Copy vocab file to ./results-google-wit-deepgram/checkpoint-9500/spiece.model
# Deleting older checkpoint [results-google-wit-deepgram/checkpoint-8000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-wit-deepgram/checkpoint-10000
# Configuration saved in ./results-google-wit-deepgram/checkpoint-10000/config.json
# Model weights saved in ./results-google-wit-deepgram/checkpoint-10000/pytorch_model.bin
# tokenizer config file saved in ./results-google-wit-deepgram/checkpoint-10000/tokenizer_config.json
# Special tokens file saved in ./results-google-wit-deepgram/checkpoint-10000/special_tokens_map.json
# Copy vocab file to ./results-google-wit-deepgram/checkpoint-10000/spiece.model
# Deleting older checkpoint [results-google-wit-deepgram/checkpoint-8500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-wit-deepgram/checkpoint-10500
# Configuration saved in ./results-google-wit-deepgram/checkpoint-10500/config.json
# Model weights saved in ./results-google-wit-deepgram/checkpoint-10500/pytorch_model.bin
# tokenizer config file saved in ./results-google-wit-deepgram/checkpoint-10500/tokenizer_config.json
# Special tokens file saved in ./results-google-wit-deepgram/checkpoint-10500/special_tokens_map.json
# Copy vocab file to ./results-google-wit-deepgram/checkpoint-10500/spiece.model
# Deleting older checkpoint [results-google-wit-deepgram/checkpoint-9000] due to args.save_total_limit
# Saving model checkpoint to ./results-google-wit-deepgram/checkpoint-11000
# Configuration saved in ./results-google-wit-deepgram/checkpoint-11000/config.json
# Model weights saved in ./results-google-wit-deepgram/checkpoint-11000/pytorch_model.bin
# tokenizer config file saved in ./results-google-wit-deepgram/checkpoint-11000/tokenizer_config.json
# Special tokens file saved in ./results-google-wit-deepgram/checkpoint-11000/special_tokens_map.json
# Copy vocab file to ./results-google-wit-deepgram/checkpoint-11000/spiece.model
# Deleting older checkpoint [results-google-wit-deepgram/checkpoint-9500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-wit-deepgram/checkpoint-11500
# Configuration saved in ./results-google-wit-deepgram/checkpoint-11500/config.json
# Model weights saved in ./results-google-wit-deepgram/checkpoint-11500/pytorch_model.bin
# tokenizer config file saved in ./results-google-wit-deepgram/checkpoint-11500/tokenizer_config.json
# Special tokens file saved in ./results-google-wit-deepgram/checkpoint-11500/special_tokens_map.json
# Copy vocab file to ./results-google-wit-deepgram/checkpoint-11500/spiece.model
# Deleting older checkpoint [results-google-wit-deepgram/checkpoint-10000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-wit-deepgram/checkpoint-12000
# Configuration saved in ./results-google-wit-deepgram/checkpoint-12000/config.json
# Model weights saved in ./results-google-wit-deepgram/checkpoint-12000/pytorch_model.bin
# tokenizer config file saved in ./results-google-wit-deepgram/checkpoint-12000/tokenizer_config.json
# Special tokens file saved in ./results-google-wit-deepgram/checkpoint-12000/special_tokens_map.json
# Copy vocab file to ./results-google-wit-deepgram/checkpoint-12000/spiece.model
# Deleting older checkpoint [results-google-wit-deepgram/checkpoint-10500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-wit-deepgram/checkpoint-12500
# Configuration saved in ./results-google-wit-deepgram/checkpoint-12500/config.json
# Model weights saved in ./results-google-wit-deepgram/checkpoint-12500/pytorch_model.bin
# tokenizer config file saved in ./results-google-wit-deepgram/checkpoint-12500/tokenizer_config.json
# Special tokens file saved in ./results-google-wit-deepgram/checkpoint-12500/special_tokens_map.json
# Copy vocab file to ./results-google-wit-deepgram/checkpoint-12500/spiece.model
# Deleting older checkpoint [results-google-wit-deepgram/checkpoint-11000] due to args.save_total_limit
# Saving model checkpoint to ./results-google-wit-deepgram/checkpoint-13000
# Configuration saved in ./results-google-wit-deepgram/checkpoint-13000/config.json
# Model weights saved in ./results-google-wit-deepgram/checkpoint-13000/pytorch_model.bin
# tokenizer config file saved in ./results-google-wit-deepgram/checkpoint-13000/tokenizer_config.json
# Special tokens file saved in ./results-google-wit-deepgram/checkpoint-13000/special_tokens_map.json
# Copy vocab file to ./results-google-wit-deepgram/checkpoint-13000/spiece.model
# Deleting older checkpoint [results-google-wit-deepgram/checkpoint-11500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-wit-deepgram/checkpoint-13500
# Configuration saved in ./results-google-wit-deepgram/checkpoint-13500/config.json
# Model weights saved in ./results-google-wit-deepgram/checkpoint-13500/pytorch_model.bin
# tokenizer config file saved in ./results-google-wit-deepgram/checkpoint-13500/tokenizer_config.json
# Special tokens file saved in ./results-google-wit-deepgram/checkpoint-13500/special_tokens_map.json
# Copy vocab file to ./results-google-wit-deepgram/checkpoint-13500/spiece.model
# Deleting older checkpoint [results-google-wit-deepgram/checkpoint-12000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-wit-deepgram/checkpoint-14000
# Configuration saved in ./results-google-wit-deepgram/checkpoint-14000/config.json
# Model weights saved in ./results-google-wit-deepgram/checkpoint-14000/pytorch_model.bin
# tokenizer config file saved in ./results-google-wit-deepgram/checkpoint-14000/tokenizer_config.json
# Special tokens file saved in ./results-google-wit-deepgram/checkpoint-14000/special_tokens_map.json
# Copy vocab file to ./results-google-wit-deepgram/checkpoint-14000/spiece.model
# Deleting older checkpoint [results-google-wit-deepgram/checkpoint-12500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-wit-deepgram/checkpoint-14500
# Configuration saved in ./results-google-wit-deepgram/checkpoint-14500/config.json
# Model weights saved in ./results-google-wit-deepgram/checkpoint-14500/pytorch_model.bin
# tokenizer config file saved in ./results-google-wit-deepgram/checkpoint-14500/tokenizer_config.json
# Special tokens file saved in ./results-google-wit-deepgram/checkpoint-14500/special_tokens_map.json
# Copy vocab file to ./results-google-wit-deepgram/checkpoint-14500/spiece.model
# Deleting older checkpoint [results-google-wit-deepgram/checkpoint-13000] due to args.save_total_limit
# Saving model checkpoint to ./results-google-wit-deepgram/checkpoint-15000
# Configuration saved in ./results-google-wit-deepgram/checkpoint-15000/config.json
# Model weights saved in ./results-google-wit-deepgram/checkpoint-15000/pytorch_model.bin
# tokenizer config file saved in ./results-google-wit-deepgram/checkpoint-15000/tokenizer_config.json
# Special tokens file saved in ./results-google-wit-deepgram/checkpoint-15000/special_tokens_map.json
# Copy vocab file to ./results-google-wit-deepgram/checkpoint-15000/spiece.model
# Deleting older checkpoint [results-google-wit-deepgram/checkpoint-13500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-wit-deepgram/checkpoint-15500
# Configuration saved in ./results-google-wit-deepgram/checkpoint-15500/config.json
# Model weights saved in ./results-google-wit-deepgram/checkpoint-15500/pytorch_model.bin
# tokenizer config file saved in ./results-google-wit-deepgram/checkpoint-15500/tokenizer_config.json
# Special tokens file saved in ./results-google-wit-deepgram/checkpoint-15500/special_tokens_map.json
# Copy vocab file to ./results-google-wit-deepgram/checkpoint-15500/spiece.model
# Deleting older checkpoint [results-google-wit-deepgram/checkpoint-14000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-wit-deepgram/checkpoint-16000
# Configuration saved in ./results-google-wit-deepgram/checkpoint-16000/config.json
# Model weights saved in ./results-google-wit-deepgram/checkpoint-16000/pytorch_model.bin
# tokenizer config file saved in ./results-google-wit-deepgram/checkpoint-16000/tokenizer_config.json
# Special tokens file saved in ./results-google-wit-deepgram/checkpoint-16000/special_tokens_map.json
# Copy vocab file to ./results-google-wit-deepgram/checkpoint-16000/spiece.model
# Deleting older checkpoint [results-google-wit-deepgram/checkpoint-14500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-wit-deepgram/checkpoint-16500
# Configuration saved in ./results-google-wit-deepgram/checkpoint-16500/config.json
# Model weights saved in ./results-google-wit-deepgram/checkpoint-16500/pytorch_model.bin
# tokenizer config file saved in ./results-google-wit-deepgram/checkpoint-16500/tokenizer_config.json
# Special tokens file saved in ./results-google-wit-deepgram/checkpoint-16500/special_tokens_map.json
# Copy vocab file to ./results-google-wit-deepgram/checkpoint-16500/spiece.model
# Deleting older checkpoint [results-google-wit-deepgram/checkpoint-15000] due to args.save_total_limit
# Saving model checkpoint to ./results-google-wit-deepgram/checkpoint-17000
# Configuration saved in ./results-google-wit-deepgram/checkpoint-17000/config.json
# Model weights saved in ./results-google-wit-deepgram/checkpoint-17000/pytorch_model.bin
# tokenizer config file saved in ./results-google-wit-deepgram/checkpoint-17000/tokenizer_config.json
# Special tokens file saved in ./results-google-wit-deepgram/checkpoint-17000/special_tokens_map.json
# Copy vocab file to ./results-google-wit-deepgram/checkpoint-17000/spiece.model
# Deleting older checkpoint [results-google-wit-deepgram/checkpoint-15500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-wit-deepgram/checkpoint-17500
# Configuration saved in ./results-google-wit-deepgram/checkpoint-17500/config.json
# Model weights saved in ./results-google-wit-deepgram/checkpoint-17500/pytorch_model.bin
# tokenizer config file saved in ./results-google-wit-deepgram/checkpoint-17500/tokenizer_config.json
# Special tokens file saved in ./results-google-wit-deepgram/checkpoint-17500/special_tokens_map.json
# Copy vocab file to ./results-google-wit-deepgram/checkpoint-17500/spiece.model
# Deleting older checkpoint [results-google-wit-deepgram/checkpoint-16000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-wit-deepgram/checkpoint-18000
# Configuration saved in ./results-google-wit-deepgram/checkpoint-18000/config.json
# Model weights saved in ./results-google-wit-deepgram/checkpoint-18000/pytorch_model.bin
# tokenizer config file saved in ./results-google-wit-deepgram/checkpoint-18000/tokenizer_config.json
# Special tokens file saved in ./results-google-wit-deepgram/checkpoint-18000/special_tokens_map.json
# Copy vocab file to ./results-google-wit-deepgram/checkpoint-18000/spiece.model
# Deleting older checkpoint [results-google-wit-deepgram/checkpoint-16500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-wit-deepgram/checkpoint-18500
# Configuration saved in ./results-google-wit-deepgram/checkpoint-18500/config.json
# Model weights saved in ./results-google-wit-deepgram/checkpoint-18500/pytorch_model.bin
# tokenizer config file saved in ./results-google-wit-deepgram/checkpoint-18500/tokenizer_config.json
# Special tokens file saved in ./results-google-wit-deepgram/checkpoint-18500/special_tokens_map.json
# Copy vocab file to ./results-google-wit-deepgram/checkpoint-18500/spiece.model
# Deleting older checkpoint [results-google-wit-deepgram/checkpoint-17000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-wit-deepgram/checkpoint-19000
# Configuration saved in ./results-google-wit-deepgram/checkpoint-19000/config.json
# Model weights saved in ./results-google-wit-deepgram/checkpoint-19000/pytorch_model.bin
# tokenizer config file saved in ./results-google-wit-deepgram/checkpoint-19000/tokenizer_config.json
# Special tokens file saved in ./results-google-wit-deepgram/checkpoint-19000/special_tokens_map.json
# Copy vocab file to ./results-google-wit-deepgram/checkpoint-19000/spiece.model
# Deleting older checkpoint [results-google-wit-deepgram/checkpoint-17500] due to args.save_total_limit
# Saving model checkpoint to ./results-google-wit-deepgram/checkpoint-19500
# Configuration saved in ./results-google-wit-deepgram/checkpoint-19500/config.json
# Model weights saved in ./results-google-wit-deepgram/checkpoint-19500/pytorch_model.bin
# tokenizer config file saved in ./results-google-wit-deepgram/checkpoint-19500/tokenizer_config.json
# Special tokens file saved in ./results-google-wit-deepgram/checkpoint-19500/special_tokens_map.json
# Copy vocab file to ./results-google-wit-deepgram/checkpoint-19500/spiece.model
# Deleting older checkpoint [results-google-wit-deepgram/checkpoint-18000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-wit-deepgram/checkpoint-20000
# Configuration saved in ./results-google-wit-deepgram/checkpoint-20000/config.json
# Model weights saved in ./results-google-wit-deepgram/checkpoint-20000/pytorch_model.bin
# tokenizer config file saved in ./results-google-wit-deepgram/checkpoint-20000/tokenizer_config.json
# Special tokens file saved in ./results-google-wit-deepgram/checkpoint-20000/special_tokens_map.json
# Copy vocab file to ./results-google-wit-deepgram/checkpoint-20000/spiece.model
# Deleting older checkpoint [results-google-wit-deepgram/checkpoint-18500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-wit-deepgram/checkpoint-20500
# Configuration saved in ./results-google-wit-deepgram/checkpoint-20500/config.json
# Model weights saved in ./results-google-wit-deepgram/checkpoint-20500/pytorch_model.bin
# tokenizer config file saved in ./results-google-wit-deepgram/checkpoint-20500/tokenizer_config.json
# Special tokens file saved in ./results-google-wit-deepgram/checkpoint-20500/special_tokens_map.json
# Copy vocab file to ./results-google-wit-deepgram/checkpoint-20500/spiece.model
# Deleting older checkpoint [results-google-wit-deepgram/checkpoint-19000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-wit-deepgram/checkpoint-21000
# Configuration saved in ./results-google-wit-deepgram/checkpoint-21000/config.json
# Model weights saved in ./results-google-wit-deepgram/checkpoint-21000/pytorch_model.bin
# tokenizer config file saved in ./results-google-wit-deepgram/checkpoint-21000/tokenizer_config.json
# Special tokens file saved in ./results-google-wit-deepgram/checkpoint-21000/special_tokens_map.json
# Copy vocab file to ./results-google-wit-deepgram/checkpoint-21000/spiece.model
# Deleting older checkpoint [results-google-wit-deepgram/checkpoint-19500] due to args.save_total_limit
# Saving model checkpoint to ./results-google-wit-deepgram/checkpoint-21500
# Configuration saved in ./results-google-wit-deepgram/checkpoint-21500/config.json
# Model weights saved in ./results-google-wit-deepgram/checkpoint-21500/pytorch_model.bin
# tokenizer config file saved in ./results-google-wit-deepgram/checkpoint-21500/tokenizer_config.json
# Special tokens file saved in ./results-google-wit-deepgram/checkpoint-21500/special_tokens_map.json
# Copy vocab file to ./results-google-wit-deepgram/checkpoint-21500/spiece.model
# Deleting older checkpoint [results-google-wit-deepgram/checkpoint-20000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-wit-deepgram/checkpoint-22000
# Configuration saved in ./results-google-wit-deepgram/checkpoint-22000/config.json
# Model weights saved in ./results-google-wit-deepgram/checkpoint-22000/pytorch_model.bin
# tokenizer config file saved in ./results-google-wit-deepgram/checkpoint-22000/tokenizer_config.json
# Special tokens file saved in ./results-google-wit-deepgram/checkpoint-22000/special_tokens_map.json
# Copy vocab file to ./results-google-wit-deepgram/checkpoint-22000/spiece.model
# Deleting older checkpoint [results-google-wit-deepgram/checkpoint-20500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-wit-deepgram/checkpoint-22500
# Configuration saved in ./results-google-wit-deepgram/checkpoint-22500/config.json
# Model weights saved in ./results-google-wit-deepgram/checkpoint-22500/pytorch_model.bin
# tokenizer config file saved in ./results-google-wit-deepgram/checkpoint-22500/tokenizer_config.json
# Special tokens file saved in ./results-google-wit-deepgram/checkpoint-22500/special_tokens_map.json
# Copy vocab file to ./results-google-wit-deepgram/checkpoint-22500/spiece.model
# Deleting older checkpoint [results-google-wit-deepgram/checkpoint-21000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-wit-deepgram/checkpoint-23000
# Configuration saved in ./results-google-wit-deepgram/checkpoint-23000/config.json
# Model weights saved in ./results-google-wit-deepgram/checkpoint-23000/pytorch_model.bin
# tokenizer config file saved in ./results-google-wit-deepgram/checkpoint-23000/tokenizer_config.json
# Special tokens file saved in ./results-google-wit-deepgram/checkpoint-23000/special_tokens_map.json
# Copy vocab file to ./results-google-wit-deepgram/checkpoint-23000/spiece.model
# Deleting older checkpoint [results-google-wit-deepgram/checkpoint-21500] due to args.save_total_limit
# Saving model checkpoint to ./results-google-wit-deepgram/checkpoint-23500
# Configuration saved in ./results-google-wit-deepgram/checkpoint-23500/config.json
# Model weights saved in ./results-google-wit-deepgram/checkpoint-23500/pytorch_model.bin
# tokenizer config file saved in ./results-google-wit-deepgram/checkpoint-23500/tokenizer_config.json
# Special tokens file saved in ./results-google-wit-deepgram/checkpoint-23500/special_tokens_map.json
# Copy vocab file to ./results-google-wit-deepgram/checkpoint-23500/spiece.model
# Deleting older checkpoint [results-google-wit-deepgram/checkpoint-22000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-wit-deepgram/checkpoint-24000
# Configuration saved in ./results-google-wit-deepgram/checkpoint-24000/config.json
# Model weights saved in ./results-google-wit-deepgram/checkpoint-24000/pytorch_model.bin
# tokenizer config file saved in ./results-google-wit-deepgram/checkpoint-24000/tokenizer_config.json
# Special tokens file saved in ./results-google-wit-deepgram/checkpoint-24000/special_tokens_map.json
# Copy vocab file to ./results-google-wit-deepgram/checkpoint-24000/spiece.model
# Deleting older checkpoint [results-google-wit-deepgram/checkpoint-22500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-wit-deepgram/checkpoint-24500
# Configuration saved in ./results-google-wit-deepgram/checkpoint-24500/config.json
# Model weights saved in ./results-google-wit-deepgram/checkpoint-24500/pytorch_model.bin
# tokenizer config file saved in ./results-google-wit-deepgram/checkpoint-24500/tokenizer_config.json
# Special tokens file saved in ./results-google-wit-deepgram/checkpoint-24500/special_tokens_map.json
# Copy vocab file to ./results-google-wit-deepgram/checkpoint-24500/spiece.model
# Deleting older checkpoint [results-google-wit-deepgram/checkpoint-23000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-wit-deepgram/checkpoint-25000
# Configuration saved in ./results-google-wit-deepgram/checkpoint-25000/config.json
# Model weights saved in ./results-google-wit-deepgram/checkpoint-25000/pytorch_model.bin
# tokenizer config file saved in ./results-google-wit-deepgram/checkpoint-25000/tokenizer_config.json
# Special tokens file saved in ./results-google-wit-deepgram/checkpoint-25000/special_tokens_map.json
# Copy vocab file to ./results-google-wit-deepgram/checkpoint-25000/spiece.model
# Deleting older checkpoint [results-google-wit-deepgram/checkpoint-23500] due to args.save_total_limit
# Saving model checkpoint to ./results-google-wit-deepgram/checkpoint-25500
# Configuration saved in ./results-google-wit-deepgram/checkpoint-25500/config.json
# Model weights saved in ./results-google-wit-deepgram/checkpoint-25500/pytorch_model.bin
# tokenizer config file saved in ./results-google-wit-deepgram/checkpoint-25500/tokenizer_config.json
# Special tokens file saved in ./results-google-wit-deepgram/checkpoint-25500/special_tokens_map.json
# Copy vocab file to ./results-google-wit-deepgram/checkpoint-25500/spiece.model
# Deleting older checkpoint [results-google-wit-deepgram/checkpoint-24000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-wit-deepgram/checkpoint-26000
# Configuration saved in ./results-google-wit-deepgram/checkpoint-26000/config.json
# Model weights saved in ./results-google-wit-deepgram/checkpoint-26000/pytorch_model.bin
# tokenizer config file saved in ./results-google-wit-deepgram/checkpoint-26000/tokenizer_config.json
# Special tokens file saved in ./results-google-wit-deepgram/checkpoint-26000/special_tokens_map.json
# Copy vocab file to ./results-google-wit-deepgram/checkpoint-26000/spiece.model
# Deleting older checkpoint [results-google-wit-deepgram/checkpoint-24500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-wit-deepgram/checkpoint-26500
# Configuration saved in ./results-google-wit-deepgram/checkpoint-26500/config.json
# Model weights saved in ./results-google-wit-deepgram/checkpoint-26500/pytorch_model.bin
# tokenizer config file saved in ./results-google-wit-deepgram/checkpoint-26500/tokenizer_config.json
# Special tokens file saved in ./results-google-wit-deepgram/checkpoint-26500/special_tokens_map.json
# Copy vocab file to ./results-google-wit-deepgram/checkpoint-26500/spiece.model
# Deleting older checkpoint [results-google-wit-deepgram/checkpoint-25000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-wit-deepgram/checkpoint-27000
# Configuration saved in ./results-google-wit-deepgram/checkpoint-27000/config.json
# Model weights saved in ./results-google-wit-deepgram/checkpoint-27000/pytorch_model.bin
# tokenizer config file saved in ./results-google-wit-deepgram/checkpoint-27000/tokenizer_config.json
# Special tokens file saved in ./results-google-wit-deepgram/checkpoint-27000/special_tokens_map.json
# Copy vocab file to ./results-google-wit-deepgram/checkpoint-27000/spiece.model
# Deleting older checkpoint [results-google-wit-deepgram/checkpoint-25500] due to args.save_total_limit
# Saving model checkpoint to ./results-google-wit-deepgram/checkpoint-27500
# Configuration saved in ./results-google-wit-deepgram/checkpoint-27500/config.json
# Model weights saved in ./results-google-wit-deepgram/checkpoint-27500/pytorch_model.bin
# tokenizer config file saved in ./results-google-wit-deepgram/checkpoint-27500/tokenizer_config.json
# Special tokens file saved in ./results-google-wit-deepgram/checkpoint-27500/special_tokens_map.json
# Copy vocab file to ./results-google-wit-deepgram/checkpoint-27500/spiece.model
# Deleting older checkpoint [results-google-wit-deepgram/checkpoint-26000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-wit-deepgram/checkpoint-28000
# Configuration saved in ./results-google-wit-deepgram/checkpoint-28000/config.json
# Model weights saved in ./results-google-wit-deepgram/checkpoint-28000/pytorch_model.bin
# tokenizer config file saved in ./results-google-wit-deepgram/checkpoint-28000/tokenizer_config.json
# Special tokens file saved in ./results-google-wit-deepgram/checkpoint-28000/special_tokens_map.json
# Copy vocab file to ./results-google-wit-deepgram/checkpoint-28000/spiece.model
# Deleting older checkpoint [results-google-wit-deepgram/checkpoint-26500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-wit-deepgram/checkpoint-28500
# Configuration saved in ./results-google-wit-deepgram/checkpoint-28500/config.json
# Model weights saved in ./results-google-wit-deepgram/checkpoint-28500/pytorch_model.bin
# tokenizer config file saved in ./results-google-wit-deepgram/checkpoint-28500/tokenizer_config.json
# Special tokens file saved in ./results-google-wit-deepgram/checkpoint-28500/special_tokens_map.json
# Copy vocab file to ./results-google-wit-deepgram/checkpoint-28500/spiece.model
# Deleting older checkpoint [results-google-wit-deepgram/checkpoint-27000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-wit-deepgram/checkpoint-29000
# Configuration saved in ./results-google-wit-deepgram/checkpoint-29000/config.json
# Model weights saved in ./results-google-wit-deepgram/checkpoint-29000/pytorch_model.bin
# tokenizer config file saved in ./results-google-wit-deepgram/checkpoint-29000/tokenizer_config.json
# Special tokens file saved in ./results-google-wit-deepgram/checkpoint-29000/special_tokens_map.json
# Copy vocab file to ./results-google-wit-deepgram/checkpoint-29000/spiece.model
# Deleting older checkpoint [results-google-wit-deepgram/checkpoint-27500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-wit-deepgram/checkpoint-29500
# Configuration saved in ./results-google-wit-deepgram/checkpoint-29500/config.json
# Model weights saved in ./results-google-wit-deepgram/checkpoint-29500/pytorch_model.bin
# tokenizer config file saved in ./results-google-wit-deepgram/checkpoint-29500/tokenizer_config.json
# ...
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-wit-deepgram/checkpoint-54500
# Configuration saved in ./results-google-wit-deepgram/checkpoint-54500/config.json
# Model weights saved in ./results-google-wit-deepgram/checkpoint-54500/pytorch_model.bin
# tokenizer config file saved in ./results-google-wit-deepgram/checkpoint-54500/tokenizer_config.json
# Special tokens file saved in ./results-google-wit-deepgram/checkpoint-54500/special_tokens_map.json
# Copy vocab file to ./results-google-wit-deepgram/checkpoint-54500/spiece.model
# Deleting older checkpoint [results-google-wit-deepgram/checkpoint-53000] due to args.save_total_limit
# Saving model checkpoint to ./results-google-wit-deepgram/checkpoint-55000
# Configuration saved in ./results-google-wit-deepgram/checkpoint-55000/config.json
# Model weights saved in ./results-google-wit-deepgram/checkpoint-55000/pytorch_model.bin
# tokenizer config file saved in ./results-google-wit-deepgram/checkpoint-55000/tokenizer_config.json
# Special tokens file saved in ./results-google-wit-deepgram/checkpoint-55000/special_tokens_map.json
# Copy vocab file to ./results-google-wit-deepgram/checkpoint-55000/spiece.model
# Deleting older checkpoint [results-google-wit-deepgram/checkpoint-53500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-wit-deepgram/checkpoint-55500
# Configuration saved in ./results-google-wit-deepgram/checkpoint-55500/config.json
# Model weights saved in ./results-google-wit-deepgram/checkpoint-55500/pytorch_model.bin
# tokenizer config file saved in ./results-google-wit-deepgram/checkpoint-55500/tokenizer_config.json
# Special tokens file saved in ./results-google-wit-deepgram/checkpoint-55500/special_tokens_map.json
# Copy vocab file to ./results-google-wit-deepgram/checkpoint-55500/spiece.model
# Deleting older checkpoint [results-google-wit-deepgram/checkpoint-54000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-wit-deepgram/checkpoint-56000
# Configuration saved in ./results-google-wit-deepgram/checkpoint-56000/config.json
# Model weights saved in ./results-google-wit-deepgram/checkpoint-56000/pytorch_model.bin
# tokenizer config file saved in ./results-google-wit-deepgram/checkpoint-56000/tokenizer_config.json
# Special tokens file saved in ./results-google-wit-deepgram/checkpoint-56000/special_tokens_map.json
# Copy vocab file to ./results-google-wit-deepgram/checkpoint-56000/spiece.model
# Deleting older checkpoint [results-google-wit-deepgram/checkpoint-54500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-wit-deepgram/checkpoint-56500
# Configuration saved in ./results-google-wit-deepgram/checkpoint-56500/config.json
# Model weights saved in ./results-google-wit-deepgram/checkpoint-56500/pytorch_model.bin
# tokenizer config file saved in ./results-google-wit-deepgram/checkpoint-56500/tokenizer_config.json
# Special tokens file saved in ./results-google-wit-deepgram/checkpoint-56500/special_tokens_map.json
# Copy vocab file to ./results-google-wit-deepgram/checkpoint-56500/spiece.model
# Deleting older checkpoint [results-google-wit-deepgram/checkpoint-55000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-wit-deepgram/checkpoint-57000
# Configuration saved in ./results-google-wit-deepgram/checkpoint-57000/config.json
# Model weights saved in ./results-google-wit-deepgram/checkpoint-57000/pytorch_model.bin
# tokenizer config file saved in ./results-google-wit-deepgram/checkpoint-57000/tokenizer_config.json
# Special tokens file saved in ./results-google-wit-deepgram/checkpoint-57000/special_tokens_map.json
# Copy vocab file to ./results-google-wit-deepgram/checkpoint-57000/spiece.model
# Deleting older checkpoint [results-google-wit-deepgram/checkpoint-55500] due to args.save_total_limit
# Saving model checkpoint to ./results-google-wit-deepgram/checkpoint-57500
# Configuration saved in ./results-google-wit-deepgram/checkpoint-57500/config.json
# Model weights saved in ./results-google-wit-deepgram/checkpoint-57500/pytorch_model.bin
# tokenizer config file saved in ./results-google-wit-deepgram/checkpoint-57500/tokenizer_config.json
# Special tokens file saved in ./results-google-wit-deepgram/checkpoint-57500/special_tokens_map.json
# Copy vocab file to ./results-google-wit-deepgram/checkpoint-57500/spiece.model
# Deleting older checkpoint [results-google-wit-deepgram/checkpoint-56000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-wit-deepgram/checkpoint-58000
# Configuration saved in ./results-google-wit-deepgram/checkpoint-58000/config.json
# Model weights saved in ./results-google-wit-deepgram/checkpoint-58000/pytorch_model.bin
# tokenizer config file saved in ./results-google-wit-deepgram/checkpoint-58000/tokenizer_config.json
# Special tokens file saved in ./results-google-wit-deepgram/checkpoint-58000/special_tokens_map.json
# Copy vocab file to ./results-google-wit-deepgram/checkpoint-58000/spiece.model
# Deleting older checkpoint [results-google-wit-deepgram/checkpoint-56500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-wit-deepgram/checkpoint-58500
# Configuration saved in ./results-google-wit-deepgram/checkpoint-58500/config.json
# Model weights saved in ./results-google-wit-deepgram/checkpoint-58500/pytorch_model.bin
# tokenizer config file saved in ./results-google-wit-deepgram/checkpoint-58500/tokenizer_config.json
# Special tokens file saved in ./results-google-wit-deepgram/checkpoint-58500/special_tokens_map.json
# Copy vocab file to ./results-google-wit-deepgram/checkpoint-58500/spiece.model
# Deleting older checkpoint [results-google-wit-deepgram/checkpoint-57000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-wit-deepgram/checkpoint-59000
# Configuration saved in ./results-google-wit-deepgram/checkpoint-59000/config.json
# Model weights saved in ./results-google-wit-deepgram/checkpoint-59000/pytorch_model.bin
# tokenizer config file saved in ./results-google-wit-deepgram/checkpoint-59000/tokenizer_config.json
# Special tokens file saved in ./results-google-wit-deepgram/checkpoint-59000/special_tokens_map.json
# Copy vocab file to ./results-google-wit-deepgram/checkpoint-59000/spiece.model
# Deleting older checkpoint [results-google-wit-deepgram/checkpoint-57500] due to args.save_total_limit
# Saving model checkpoint to ./results-google-wit-deepgram/checkpoint-59500
# Configuration saved in ./results-google-wit-deepgram/checkpoint-59500/config.json
# Model weights saved in ./results-google-wit-deepgram/checkpoint-59500/pytorch_model.bin
# tokenizer config file saved in ./results-google-wit-deepgram/checkpoint-59500/tokenizer_config.json
# Special tokens file saved in ./results-google-wit-deepgram/checkpoint-59500/special_tokens_map.json
# Copy vocab file to ./results-google-wit-deepgram/checkpoint-59500/spiece.model
# Deleting older checkpoint [results-google-wit-deepgram/checkpoint-58000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-wit-deepgram/checkpoint-60000
# Configuration saved in ./results-google-wit-deepgram/checkpoint-60000/config.json
# Model weights saved in ./results-google-wit-deepgram/checkpoint-60000/pytorch_model.bin
# tokenizer config file saved in ./results-google-wit-deepgram/checkpoint-60000/tokenizer_config.json
# Special tokens file saved in ./results-google-wit-deepgram/checkpoint-60000/special_tokens_map.json
# Copy vocab file to ./results-google-wit-deepgram/checkpoint-60000/spiece.model
# Deleting older checkpoint [results-google-wit-deepgram/checkpoint-58500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-wit-deepgram/checkpoint-60500
# Configuration saved in ./results-google-wit-deepgram/checkpoint-60500/config.json
# Model weights saved in ./results-google-wit-deepgram/checkpoint-60500/pytorch_model.bin
# tokenizer config file saved in ./results-google-wit-deepgram/checkpoint-60500/tokenizer_config.json
# Special tokens file saved in ./results-google-wit-deepgram/checkpoint-60500/special_tokens_map.json
# Copy vocab file to ./results-google-wit-deepgram/checkpoint-60500/spiece.model
# Deleting older checkpoint [results-google-wit-deepgram/checkpoint-59000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-wit-deepgram/checkpoint-61000
# Configuration saved in ./results-google-wit-deepgram/checkpoint-61000/config.json
# Model weights saved in ./results-google-wit-deepgram/checkpoint-61000/pytorch_model.bin
# tokenizer config file saved in ./results-google-wit-deepgram/checkpoint-61000/tokenizer_config.json
# Special tokens file saved in ./results-google-wit-deepgram/checkpoint-61000/special_tokens_map.json
# Copy vocab file to ./results-google-wit-deepgram/checkpoint-61000/spiece.model
# Deleting older checkpoint [results-google-wit-deepgram/checkpoint-59500] due to args.save_total_limit
# Saving model checkpoint to ./results-google-wit-deepgram/checkpoint-61500
# Configuration saved in ./results-google-wit-deepgram/checkpoint-61500/config.json
# Model weights saved in ./results-google-wit-deepgram/checkpoint-61500/pytorch_model.bin
# tokenizer config file saved in ./results-google-wit-deepgram/checkpoint-61500/tokenizer_config.json
# Special tokens file saved in ./results-google-wit-deepgram/checkpoint-61500/special_tokens_map.json
# Copy vocab file to ./results-google-wit-deepgram/checkpoint-61500/spiece.model
# Deleting older checkpoint [results-google-wit-deepgram/checkpoint-60000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-wit-deepgram/checkpoint-62000
# Configuration saved in ./results-google-wit-deepgram/checkpoint-62000/config.json
# Model weights saved in ./results-google-wit-deepgram/checkpoint-62000/pytorch_model.bin
# tokenizer config file saved in ./results-google-wit-deepgram/checkpoint-62000/tokenizer_config.json
# Special tokens file saved in ./results-google-wit-deepgram/checkpoint-62000/special_tokens_map.json
# Copy vocab file to ./results-google-wit-deepgram/checkpoint-62000/spiece.model
# Deleting older checkpoint [results-google-wit-deepgram/checkpoint-60500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-wit-deepgram/checkpoint-62500
# Configuration saved in ./results-google-wit-deepgram/checkpoint-62500/config.json
# Model weights saved in ./results-google-wit-deepgram/checkpoint-62500/pytorch_model.bin
# tokenizer config file saved in ./results-google-wit-deepgram/checkpoint-62500/tokenizer_config.json
# Special tokens file saved in ./results-google-wit-deepgram/checkpoint-62500/special_tokens_map.json
# Copy vocab file to ./results-google-wit-deepgram/checkpoint-62500/spiece.model
# Deleting older checkpoint [results-google-wit-deepgram/checkpoint-61000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-wit-deepgram/checkpoint-63000
# Configuration saved in ./results-google-wit-deepgram/checkpoint-63000/config.json
# Model weights saved in ./results-google-wit-deepgram/checkpoint-63000/pytorch_model.bin
# tokenizer config file saved in ./results-google-wit-deepgram/checkpoint-63000/tokenizer_config.json
# Special tokens file saved in ./results-google-wit-deepgram/checkpoint-63000/special_tokens_map.json
# Copy vocab file to ./results-google-wit-deepgram/checkpoint-63000/spiece.model
# Deleting older checkpoint [results-google-wit-deepgram/checkpoint-61500] due to args.save_total_limit
# Saving model checkpoint to ./results-google-wit-deepgram/checkpoint-63500
# Configuration saved in ./results-google-wit-deepgram/checkpoint-63500/config.json
# Model weights saved in ./results-google-wit-deepgram/checkpoint-63500/pytorch_model.bin
# tokenizer config file saved in ./results-google-wit-deepgram/checkpoint-63500/tokenizer_config.json
# Special tokens file saved in ./results-google-wit-deepgram/checkpoint-63500/special_tokens_map.json
# Copy vocab file to ./results-google-wit-deepgram/checkpoint-63500/spiece.model
# Deleting older checkpoint [results-google-wit-deepgram/checkpoint-62000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-wit-deepgram/checkpoint-64000
# Configuration saved in ./results-google-wit-deepgram/checkpoint-64000/config.json
# Model weights saved in ./results-google-wit-deepgram/checkpoint-64000/pytorch_model.bin
# tokenizer config file saved in ./results-google-wit-deepgram/checkpoint-64000/tokenizer_config.json
# Special tokens file saved in ./results-google-wit-deepgram/checkpoint-64000/special_tokens_map.json
# Copy vocab file to ./results-google-wit-deepgram/checkpoint-64000/spiece.model
# Deleting older checkpoint [results-google-wit-deepgram/checkpoint-62500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-wit-deepgram/checkpoint-64500
# Configuration saved in ./results-google-wit-deepgram/checkpoint-64500/config.json
# Model weights saved in ./results-google-wit-deepgram/checkpoint-64500/pytorch_model.bin
# tokenizer config file saved in ./results-google-wit-deepgram/checkpoint-64500/tokenizer_config.json
# Special tokens file saved in ./results-google-wit-deepgram/checkpoint-64500/special_tokens_map.json
# Copy vocab file to ./results-google-wit-deepgram/checkpoint-64500/spiece.model
# Deleting older checkpoint [results-google-wit-deepgram/checkpoint-63000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
# Saving model checkpoint to ./results-google-wit-deepgram/checkpoint-65000
# Configuration saved in ./results-google-wit-deepgram/checkpoint-65000/config.json
# Model weights saved in ./results-google-wit-deepgram/checkpoint-65000/pytorch_model.bin
# tokenizer config file saved in ./results-google-wit-deepgram/checkpoint-65000/tokenizer_config.json
# Special tokens file saved in ./results-google-wit-deepgram/checkpoint-65000/special_tokens_map.json
# Copy vocab file to ./results-google-wit-deepgram/checkpoint-65000/spiece.model
# Deleting older checkpoint [results-google-wit-deepgram/checkpoint-63500] due to args.save_total_limit
# Saving model checkpoint to ./results-google-wit-deepgram/checkpoint-65500
# Configuration saved in ./results-google-wit-deepgram/checkpoint-65500/config.json
# Model weights saved in ./results-google-wit-deepgram/checkpoint-65500/pytorch_model.bin
# tokenizer config file saved in ./results-google-wit-deepgram/checkpoint-65500/tokenizer_config.json
# Special tokens file saved in ./results-google-wit-deepgram/checkpoint-65500/special_tokens_map.json
# Copy vocab file to ./results-google-wit-deepgram/checkpoint-65500/spiece.model
# Deleting older checkpoint [results-google-wit-deepgram/checkpoint-64000] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 2615
#   Batch size = 16
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=65500, training_loss=0.03787209140981427, metrics={'train_runtime': 24955.0401, 'train_samples_per_second': 41.984, 'train_steps_per_second': 2.625, 'total_flos': 1.32935255064576e+17, 'train_loss': 0.03787209140981427, 'epoch': 100.0})

# %%
import torch

device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")

results = []

for batch in tokenized_datasets_valid:
  y_pred = model.generate(torch.tensor([batch['input_ids']]).to(device))

  for i in range(len(y_pred)):
    results.append({
      'input': tokenizer.decode(batch['input_ids'], skip_special_tokens=True),
      'output': tokenizer.decode(y_pred[i], skip_special_tokens=True),
      'label': tokenizer.decode(batch['labels'], skip_special_tokens=True),
    })

results_df = pd.DataFrame(results)
results_df.to_csv(DS_DIR + 'google-wit-deepgram-results.csv')
